# %%
save_path = '/content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvidia-smi
# Out:
# Wed Nov 24 04:47:23 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    27W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import shutil
shutil.copyfile('/content/drive/MyDrive/bio-data/ok.zip', './ok.zip')
# !unzip ok.zip

shutil.copyfile('/content/drive/MyDrive/bio-data/training-needs.zip', './train.zip')
# !unzip train.zip
# Out:
# Archive:  ok.zip
#    creating: Test/
#   inflating: Test/5G6UA.fasta
#   inflating: Test/5G6UA.hhm
#   inflating: Test/5G6UA.pssm
#   inflating: Test/5G6UA.spotcon
#   inflating: Test/5G6UA.ss
#   inflating: Test/5H7KA.fasta
#   inflating: Test/5H7KA.hhm
#   inflating: Test/5H7KA.pssm
#   inflating: Test/5H7KA.spotcon
#   inflating: Test/5H7KA.ss
#   inflating: 0norm_data.p
#   inflating: 1norm_data.p
#   inflating: 5norm_data.p
#   inflating: aa_phy7
#   inflating: config.py
#   inflating: GenerateBaseFeature.py
#   inflating: GenerateForWindow10.py
#   inflating: GenerateForWindow20.py
#   inflating: GenerateForWindow50.py
#   inflating: GenerateLengthList.py
#   inflating: list_test
#   inflating: SAINT_ensemble.py
#   inflating: SAINT_single_base_model.py
# Archive:  train.zip
#    creating: training-needs/
#   inflating: training-needs/trainX.npy
#   inflating: training-needs/validationX.npy
#   inflating: training-needs/test2016X.npy
#   inflating: training-needs/test2018X.npy
#   inflating: training-needs/trainY.npy
#   inflating: training-needs/validationY.npy
#   inflating: training-needs/test2016Y.npy
#   inflating: training-needs/test2018Y.npy
#   inflating: training-needs/trainAttM.npy
#   inflating: training-needs/validationAttM.npy
#   inflating: training-needs/test2016AttM.npy
#   inflating: training-needs/test2018AttM.npy

# %%
########### Select Tensorflow and Keras Version
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
########## imports
# tensorflow and keras functions
import tensorflow as tensorflow
import tensorflow as tf
import keras
from keras import backend as K
from keras.models import Sequential
from keras.models import Model
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM, GRU
from keras.layers import Input,SpatialDropout1D, Embedding, LSTM, Dense, merge, Convolution2D, Lambda, GRU, TimeDistributed, Reshape, Permute, Convolution1D, Masking, Bidirectional
from keras.optimizers import Adam
from keras.layers import concatenate
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint
from keras import optimizers, callbacks
from keras.layers import Layer
from keras.initializers import Ones, Zeros
from keras.layers import Layer
from keras.engine.topology import Layer
from keras.layers import add
from keras.layers import RepeatVector, Multiply, Flatten, Dot, Softmax, Lambda
from keras import backend
from keras.layers import RepeatVector
from keras.layers import Embedding, Add, concatenate
from keras.layers import BatchNormalization, Dropout

# python built-in
from time import time
import numpy as np
import gc
import random
import math

# custom 
import config
from config import *
from GenerateBaseFeature import generateBaseDataset
from GenerateLengthList import generateLengthlistAndAttentionMask

print(tensorflow.__version__)
print(keras.__version__)
# Out:
# 1.15.2
# 2.3.1
# Using TensorFlow backend.

# %%
def truncated_accuracy(y_true, y_predict):
    mask = K.sum(y_true, axis=2)
    y_pred_labels = K.cast(K.argmax(y_predict, axis=2), 'float32')
    y_true_labels = K.cast(K.argmax(y_true, axis=2), 'float32')
    is_same = K.cast(K.equal(
        y_true_labels, y_pred_labels), 'float32')
    num_same = K.sum(is_same * mask, axis=1)
    lengths = K.sum(mask, axis=1)
    # return K.cast(K.sum(num_same, axis=0) / K.sum(lengths, axis=0), 'float32')
    return Lambda(lambda x: x[0]/x[1])([K.sum(num_same, axis=0), K.sum(lengths, axis=0)])

class LayerNormalization(Layer):
    def __init__(self, eps: float = 1e-5, **kwargs) -> None:
        self.eps = eps
        super().__init__(**kwargs)

    def build(self, input_shape):
        self.gamma = self.add_weight(name='gamma', shape=input_shape[-1:], initializer=Ones(), trainable=True)
        self.beta = self.add_weight(name='beta', shape=input_shape[-1:], initializer=Zeros(), trainable=True)
        super().build(input_shape)

    def call(self, x, **kwargs):
        u = K.mean(x, axis=-1, keepdims=True)
        s = K.mean(K.square(x - u), axis=-1, keepdims=True)
        z = (x - u) / K.sqrt(s + self.eps)
        return self.gamma * z + self.beta

    def compute_output_shape(self, input_shape):
        return input_shape

    def get_config(self):
        config = {
            'eps': self.eps,
        }
        base_config = super().get_config()
        return dict(list(base_config.items()) + list(config.items()))

class MyLayer(Layer):
    def __init__(self, **kwargs):
        super(MyLayer, self).__init__(**kwargs)

    def build(self, input_shape):

        self._x = K.variable(0.2)
        self._x._trainable = True
        self.trainable_weights = [self._x]

        super(MyLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, x):
        A, B = x
        result = add([self._x*A ,(1-self._x)*B])
        return result

    def compute_output_shape(self, input_shape):
        return input_shape[0]

def attention(activations):
#https://arxiv.org/pdf/1703.03130.pdf
    d_a = 10
    r = 1
    units = activations.shape[2]
    #print(activations.shape)
    attention = TimeDistributed(Dense(d_a, activation='tanh', use_bias=False))(activations)
    attention = Dropout(.5)(attention)
    #print(attention.shape)
    attention = TimeDistributed(Dense(r, activation='softmax', use_bias=False))(activations) 
    #print(attention.shape)
    attention = Flatten()(attention)
    #attention = Activation('softmax')(attention)
    attention = RepeatVector(units)(attention)
    #print(attention.shape)
    attention = Permute([2, 1])(attention)
    #print(attention.shape)

    # apply the attention
    sent_representation = Multiply()([activations, attention])
    #sent_representation = Lambda(lambda xin: K.dot(xin[0], xin[1]))([attention, activations])
    #print(sent_representation.shape)
    #sent_representation = Lambda(lambda xin: K.sum(xin, axis=1))(sent_representation)
    #print(sent_representation.shape)
    return sent_representation

def shape_list(x):
    #   https://github.com/Separius/BERT-keras/blob/master/transformer/funcs.py
    if backend.backend() != 'theano':
        tmp = backend.int_shape(x)
    else:
        tmp = x.shape
    tmp = list(tmp)
    tmp[0] = -1
    return tmp

def attention_scaled_dot(activations, attention_mask, head = 1): #, length):
#https://arxiv.org/pdf/1706.03762.pdf
    units = int(activations.shape[2])
    words = int(activations.shape[1])
    print('Activations.shape: ',activations.shape)
    _drop_rate_ = .1
    hidden_dimension = int(units/head)
    Q = TimeDistributed(Dense(hidden_dimension, activation=None, use_bias=False))(activations)
    Q = Dropout(_drop_rate_)(Q)
    K = TimeDistributed(Dense(hidden_dimension, activation=None, use_bias=False))(activations)
    K = Dropout(_drop_rate_)(K)
    V = TimeDistributed(Dense(hidden_dimension, activation=None, use_bias=False))(activations)
    V = Dropout(_drop_rate_)(V)
    print('Q.shape: ',Q.shape)
    QK_T = Dot(axes=-1, normalize=False)([Q,K]) # list of two tensors
    print('QK_T.shape: ', QK_T.shape)
    """normalize: Whether to L2-normalize samples along the dot product axis before taking the dot product. If set to True, then the output of the dot product is the cosine proximity between the two samples."""
    QK_T = Lambda( lambda inp: inp[0]/ backend.sqrt(backend.cast(shape_list(inp[1])[-1], backend.floatx())))([QK_T, V])
    print('QK_T.shape: ', QK_T.shape)
    
#     cropping = np.zeros(QK_T.shape[1])
#     cropping[length:] = (-10**6) * np.ones(int(QK_T.shape[1])-length)
#     QK_T = QK_T + cropping
    print('att mask origin shape: ',attention_mask.shape)
    attention_mask__ = RepeatVector(int(QK_T.shape[1]))(attention_mask)
    print('att mask shape: ',attention_mask__.shape)
    QK_T = Add()([QK_T, attention_mask__])
    print('Add QK and mask: ',attention_mask__.shape)
    QK_T = Softmax(axis=-1)(QK_T)
    QK_T = Dropout(_drop_rate_)(QK_T)
    #print(V.shape)
    V = Permute([2, 1])(V)
    print('V premute shape: ', V.shape)
    V_prime = Dot(axes=-1, normalize=False)([QK_T,V]) # list of two tensors
    print('V_prime shape: ', V_prime.shape)
    return V_prime

def _get_pos_encoding_matrix(protein_len: int, d_emb: int) -> np.array:
    pos_enc = np.array(
        [[pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)] if pos != 0 else np.zeros(d_emb) for pos in
         range(protein_len)], dtype=np.float32)
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2])  # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2])  # dim 2i+1
    return pos_enc

def embeddings(inputs):
    gene_ids, pos_ids = inputs
    gene_vocab_len = 22
    protein_len = 700
    output_dim = 50
    gene_embedding = Embedding(gene_vocab_len, output_dim, input_length=protein_len,
                                              name='GeneEmbedding')(gene_ids)

    pos_embedding = Embedding(protein_len, output_dim, trainable=False, input_length=protein_len,
                                              name='PositionEmbedding',
                                              weights=[_get_pos_encoding_matrix(protein_len, output_dim)])(pos_ids)

    summation = Add(name='AddEmbeddings')([Dropout(.1, name='EmbeddingDropOut1')(gene_embedding), 
                                           Dropout(.1, name='EmbeddingDropOut2')(pos_embedding)])
    
#     summation = concatenate([Dropout(.1, name='EmbeddingDropOut1')(gene_embedding), 
#                              Dropout(.1, name='EmbeddingDropOut2')(pos_embedding)])
    
    summation = LayerNormalization(1e-5)(summation)
    return summation

def gene_embeddings(gene_ids, output_dim=50):
    gene_vocab_len = 22
    protein_len = 700
    
    gene_emb = Dropout(.1)(Embedding(gene_vocab_len, output_dim, input_length=protein_len,
                               name='GeneEmbedding')(gene_ids))

    gene_emb = LayerNormalization(1e-5)(gene_emb)
    return gene_emb


def position_embedding(pos_ids, output_dim=50):
    #gene_vocab_len = 22
    protein_len = 700
    output_dim = int(output_dim)

    pos_emb = Dropout(.1)(Embedding(protein_len, output_dim, trainable=False, input_length=protein_len,
                        #name='PositionEmbedding',
                        weights=[_get_pos_encoding_matrix(protein_len, output_dim)])(pos_ids))
    
    pos_emb = LayerNormalization(1e-5)(pos_emb)
    return pos_emb


def attention_module(x, attention_mask, pos_ids=None, drop_rate=.1, ccnt=None, head = 1):
    
    original_dim = int(x.shape[-1])
    
    if ccnt is not None:
        print('aatt--------x1-> '+str(x.shape))
        print('original dim--------x1-> '+str(original_dim))
    if pos_ids is not None:
        pos_embedding = position_embedding(pos_ids=pos_ids, output_dim=original_dim)
        #x = concatenate([x, pos_embedding])
        x = Add()([x, pos_embedding])

    if ccnt is not None:
        print('aatt--------x2-> '+str(x.shape))

    
    att_layer_head1 = attention_scaled_dot(x, attention_mask, head) ## our code
    att_layer_head2 = attention_scaled_dot(x, attention_mask, head) ## our code

    att_layer = keras.layers.Concatenate(axis = -1)([att_layer_head1,att_layer_head2]) ## our code
    if ccnt is not None:
        print('aatt--------att_layer1-> '+str(att_layer.shape))
    att_layer = Dropout(drop_rate)(att_layer)

    att_layer = TimeDistributed(Dense(original_dim, activation=None, use_bias=False))(att_layer) ## our code

    if ccnt is not None:
        print('aatt--------att_layer2-> '+str(att_layer.shape))
    x = MyLayer()([att_layer, x])

    if ccnt is not None:
        print('aatt--------my-> '+str(x.shape))
    x = Dropout(drop_rate)(x)
    x = BatchNormalization()(x)
#     if False:
#         # reduce dim
#         x = Convolution1D(original_dim, 1, activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
#         x = Dropout(drop_rate*2)(x)
#         x = BatchNormalization()(x)
    # ccnt +=1
    return x

def inceptionBlock(x):
    _drop_rate_ = .1
    x = BatchNormalization()(x)
    print('inceptionblock before CONV '+ str(x.shape))
    conv1_1 = Convolution1D(100, 1, activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    print('inceptionblock after CONV '+ str(conv1_1.shape))
    conv1_1 = Dropout(_drop_rate_)(conv1_1) #https://www.quora.com/Can-l-combine-dropout-and-l2-regularization
    conv1_1 = BatchNormalization()(conv1_1)
    
    conv2_1 = Convolution1D(100, 1, activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    conv2_1 = Dropout(_drop_rate_)(conv2_1)
    conv2_1 = BatchNormalization()(conv2_1)
    conv2_2 = Convolution1D(100, 3, activation='relu', padding='same', kernel_regularizer=l2(0.001))(conv2_1)
    conv2_2 = Dropout(_drop_rate_)(conv2_2)
    conv2_2 = BatchNormalization()(conv2_2)
    
    conv3_1 = Convolution1D(100, 1, activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    conv3_1 = Dropout(_drop_rate_)(conv3_1)
    conv3_1 = BatchNormalization()(conv3_1)
    conv3_2 = Convolution1D(100, 3, activation='relu', padding='same', kernel_regularizer=l2(0.001))(conv3_1)
    conv3_2 = Dropout(_drop_rate_)(conv3_2)
    conv3_2 = BatchNormalization()(conv3_2)
    conv3_3 = Convolution1D(100, 3, activation='relu', padding='same', kernel_regularizer=l2(0.001))(conv3_2)
    conv3_3 = Dropout(_drop_rate_)(conv3_3)
    conv3_3 = BatchNormalization()(conv3_3)
    conv3_4 = Convolution1D(100, 3, activation='relu', padding='same', kernel_regularizer=l2(0.001))(conv3_3)
    conv3_4 = Dropout(_drop_rate_)(conv3_4)
    conv3_4 = BatchNormalization()(conv3_4)
    
    concat = concatenate([conv1_1, conv2_2, conv3_4])
    concat = BatchNormalization()(concat)
    
    return concat

def deep3iBLock_with_attention(x, attention_mask, pos_ids=None):
    print('x-> '+str(x.shape))
    block1_1 = inceptionBlock(x)
    print('block1_1-> '+str(block1_1.shape))
    block1_1 = attention_module(block1_1, attention_mask, pos_ids,ccnt=1, head = 2)
    print('block1_1-> '+str(block1_1.shape))

    block2_1 = inceptionBlock(x)
    print('block2_1-> '+str(block2_1.shape))
    block2_2 = inceptionBlock(block2_1)
    print('block2_1-> '+str(block2_1.shape))
    block2_2 = attention_module(block2_2, attention_mask, pos_ids, head = 2)
    print('block2_2-> '+str(block2_2.shape))


    block3_1 = inceptionBlock(x)
    block3_2 = inceptionBlock(block3_1)
    block3_3 = inceptionBlock(block3_2)
    block3_4 = inceptionBlock(block3_3)
    print('block3_4-> '+str(block3_4.shape))
    block3_4 = attention_module(block3_4, attention_mask, pos_ids, head = 2)
    print('block3_4-> '+str(block3_4.shape))

    concat = concatenate([block1_1, block2_2, block3_4])
    concat = BatchNormalization()(concat)
    
    return concat

def get_model(num_feature):
#   pssm_input = Input(shape=(700,21,), name='pssm_input')
#   seq_input = Input(shape=(700,22,), name='seq_input')
  _drop_rate_ = .4
  main_input = Input(shape=(700,num_feature,), name='main_input')
  attention_mask = Input(shape=(700,), name='attention_mask')
  pos_ids = Input(shape=(700,), name='position_input', dtype='int32')
  
  #pos_emb = position_embedding(pos_ids, output_dim=50)
#   main_input = concatenate([seq_input, pssm_input])
  
  block1 = deep3iBLock_with_attention(main_input, attention_mask, pos_ids)
#   att_layer_4 = attention_scaled_dot(block1)
#   block1 = MyLayer()([att_layer_4 ,block1])
#   block1 = BatchNormalization()(block1)
  
  block2 = deep3iBLock_with_attention(block1, attention_mask, pos_ids)
  block2 = attention_module(block2, attention_mask, pos_ids, head = 2)
  
  conv11 = Convolution1D(100, 11, activation='relu', padding='same', kernel_regularizer=l2(0.001))(block2)
#   conv11 = BatchNormalization()(conv11)
  conv11 = attention_module(conv11, attention_mask, pos_ids, head = 2)

  dense1 = TimeDistributed(Dense(units=256,activation='relu'))(conv11)
  dense1 = Dropout(_drop_rate_)(dense1)
  dense1 = attention_module(dense1, attention_mask, pos_ids, head = 2)
  
  print('before final: -------------------' + str(dense1.shape))
  main_output = TimeDistributed(Dense(units=8,activation='softmax', name='main_output'))(dense1)
  print('after final: -------------------' + str(main_output.shape))
#   main_output = TimeDistributed(Dense(units=8,activation='softmax', name='main_output'))(block1)
  
  model = Model([main_input, attention_mask, pos_ids],main_output)
  return model

class StepDecay():
  def __init__(self, initAlpha=0.0005, factor=0.9, dropEvery=60, min_lr=0.00001):
    self.initAlpha = initAlpha
    self.factor = factor
    self.dropEvery = dropEvery
    self.min_lr = min_lr

  def __call__(self, epoch):
    exp = np.floor((epoch + 1) / self.dropEvery)
    alpha = self.initAlpha * (self.factor ** exp)
    if float(alpha) > self.min_lr:
        print('lr:', alpha)
        return float(alpha)
    else:
        print('lr:', self.min_lr)
        return self.min_lr
    
def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
        return optimizer.lr
    return lr

# %%
model = get_model(num_feature=71)
# Out:
# x-> (?, 700, 71)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# inceptionblock before CONV (?, 700, 71)
# inceptionblock after CONV (?, 700, 100)
# block1_1-> (?, 700, 300)
# aatt--------x1-> (?, 700, 300)
# original dim--------x1-> 300
# aatt--------x2-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# aatt--------att_layer1-> (?, 700, 300)
# aatt--------att_layer2-> (?, 700, 300)
# tracking <tf.Variable 'my_layer_1/Variable:0' shape=() dtype=float32> _x
# aatt--------my-> (?, 700, 300)
# block1_1-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 71)
# inceptionblock after CONV (?, 700, 100)
# block2_1-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# block2_1-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# tracking <tf.Variable 'my_layer_2/Variable:0' shape=() dtype=float32> _x
# block2_2-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 71)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# block3_4-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# tracking <tf.Variable 'my_layer_3/Variable:0' shape=() dtype=float32> _x
# block3_4-> (?, 700, 300)
# x-> (?, 700, 900)
# inceptionblock before CONV (?, 700, 900)
# inceptionblock after CONV (?, 700, 100)
# block1_1-> (?, 700, 300)
# aatt--------x1-> (?, 700, 300)
# original dim--------x1-> 300
# aatt--------x2-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# aatt--------att_layer1-> (?, 700, 300)
# aatt--------att_layer2-> (?, 700, 300)
# tracking <tf.Variable 'my_layer_4/Variable:0' shape=() dtype=float32> _x
# aatt--------my-> (?, 700, 300)
# block1_1-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 900)
# inceptionblock after CONV (?, 700, 100)
# block2_1-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# block2_1-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# tracking <tf.Variable 'my_layer_5/Variable:0' shape=() dtype=float32> _x
# block2_2-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 900)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# block3_4-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# tracking <tf.Variable 'my_layer_6/Variable:0' shape=() dtype=float32> _x
# block3_4-> (?, 700, 300)
# Activations.shape:  (?, 700, 900)
# Q.shape:  (?, 700, 450)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 450, 700)
# V_prime shape:  (?, 700, 450)
# Activations.shape:  (?, 700, 900)
# Q.shape:  (?, 700, 450)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 450, 700)
# V_prime shape:  (?, 700, 450)
# tracking <tf.Variable 'my_layer_7/Variable:0' shape=() dtype=float32> _x
# Activations.shape:  (?, 700, 100)
# Q.shape:  (?, 700, 50)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 50, 700)
# V_prime shape:  (?, 700, 50)
# Activations.shape:  (?, 700, 100)
# Q.shape:  (?, 700, 50)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 50, 700)
# V_prime shape:  (?, 700, 50)
# tracking <tf.Variable 'my_layer_8/Variable:0' shape=() dtype=float32> _x
# Activations.shape:  (?, 700, 256)
# Q.shape:  (?, 700, 128)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 128, 700)
# V_prime shape:  (?, 700, 128)
# Activations.shape:  (?, 700, 256)
# Q.shape:  (?, 700, 128)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 128, 700)
# V_prime shape:  (?, 700, 128)
# tracking <tf.Variable 'my_layer_9/Variable:0' shape=() dtype=float32> _x
# before final: -------------------(?, 700, 256)
# after final: -------------------(?, 700, 8)

# %%
# !pip install 'h5py==2.10.0' --force-reinstall
# Out:
# Collecting h5py==2.10.0
#   Downloading h5py-2.10.0-cp37-cp37m-manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 8.2 MB/s
# Collecting six
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting numpy>=1.7
#   Downloading numpy-1.21.4-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
#      |████████████████████████████████| 15.7 MB 33.5 MB/s
# Installing collected packages: six, numpy, h5py
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.19.5
#     Uninstalling numpy-1.19.5:
#       Successfully uninstalled numpy-1.19.5
#   Attempting uninstall: h5py
#     Found existing installation: h5py 3.1.0
#     Uninstalling h5py-3.1.0:
#       Successfully uninstalled h5py-3.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# yellowbrick 1.3.post1 requires numpy<1.20,>=1.16.0, but you have numpy 1.21.4 which is incompatible.
# google-colab 1.0.0 requires six~=1.15.0, but you have six 1.16.0 which is incompatible.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed h5py-2.10.0 numpy-1.21.4 six-1.16.0

# %%
model.summary()

# %%
model.load_weights('/content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.758766.hdf5')
# model.load_weights('./SAINT_win0_weights.h5')

# %% [markdown]
# # Our Code

# %% [markdown]
# ## Callbacks

# %%
def set_es(loss_to_monitor = 'val_truncated_accuracy', patience = 20, verbosity = True):
    global es_callback
    es_callback = tensorflow.keras.callbacks.EarlyStopping(monitor=loss_to_monitor, patience=patience, verbose=verbosity)

set_es()

# %%
# Learning rate
import matplotlib.pyplot as plt

start_lr = 1e-7
min_lr = 1e-5
max_lr = 5e-4
rampup_epochs = 10
sustain_epochs = 0
exp_decay = .96
d_model = 512

current_epoch = 0

def lrfn(epoch):
    global current_epoch

    if current_epoch < rampup_epochs:
        lr = (max_lr - start_lr)/rampup_epochs * current_epoch + start_lr
        current_epoch += 1
        return lr
    elif current_epoch < rampup_epochs + sustain_epochs:
        current_epoch += 1
        return max_lr
    else:
        lr = (max_lr - min_lr) * exp_decay**(current_epoch-rampup_epochs-sustain_epochs) + min_lr
        current_epoch += 1
        return lr
    # steps_per_epoch = 500
    # step = epoch * steps_per_epoch
    # warmup_steps = rampup_epochs * steps_per_epoch
    # arg1 = step ** -0.5
    # arg2 = step * (warmup_steps ** -1.5)

    # return (d_model**-0.5) * min(arg1, arg2)

lr_callback = tensorflow.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

rang = np.arange(150)
y = [lrfn(x) for x in rang]
print(y)
plt.plot(rang, y)
current_epoch = 84
# Out:
# [1e-07, 5.009000000000001e-05, 0.00010008000000000002, 0.00015007000000000003, 0.00020006000000000003, 0.00025005000000000003, 0.00030004000000000006, 0.00035003000000000004, 0.00040002000000000006, 0.0004500100000000001, 0.0005, 0.00048039999999999997, 0.000461584, 0.0004435206399999999, 0.00042617981439999997, 0.00040953262182399995, 0.0003935513169510399, 0.0003782092642729983, 0.0003634808937020784, 0.00034934165795399524, 0.0003357679916358354, 0.000322737271970402, 0.0003102277810915859, 0.00029821866984792246, 0.00028668992305400554, 0.0002756223261318453, 0.0002649974330865715, 0.0002547975357631086, 0.00024500563433258425, 0.00023560540895928086, 0.00022658119260090962, 0.0002179179448968732, 0.00020960122710099829, 0.00020161717801695834, 0.00019395249089628, 0.0001865943912604288, 0.00017953061561001163, 0.0001727493909856112, 0.00016623941534618672, 0.00015998983873233925, 0.00015399024518304567, 0.00014823063537572386, 0.00014270140996069488, 0.0001373933535622671, 0.0001322976194197764, 0.00012740571464298534, 0.00012270948605726592, 0.00011820110661497527, 0.00011387306235037627, 0.0001097181398563612, 0.00010572941426210676, 0.00010190023769162248, 9.822422818395758e-05, 9.469525905659927e-05, 9.13074486943353e-05, 8.805515074656189e-05, 8.49329447166994e-05, 8.193562692803143e-05, 7.905820185091017e-05, 7.629587377687376e-05, 7.36440388257988e-05, 7.109827727276686e-05, 6.865434618185618e-05, 6.630817233458192e-05, 6.405584544119865e-05, 6.18936116235507e-05, 5.981786715860867e-05, 5.7825152472264316e-05, 5.5912146373373745e-05, 5.407566051843879e-05, 5.231263409770124e-05, 5.0620128733793184e-05, 4.8995323584441456e-05, 4.74355106410638e-05, 4.593809021542125e-05, 4.4500566606804394e-05, 4.312054394253222e-05, 4.179572218483093e-05, 4.0523893297437694e-05, 3.930293756554018e-05, 3.8130820062918575e-05, 3.700558726040183e-05, 3.592536376998576e-05, 3.4888349219186326e-05, 3.389281525041887e-05, 3.293710264040212e-05, 3.201961853478603e-05, 3.113883379339459e-05, 3.0293280441658803e-05, 2.9481549223992448e-05, 2.8702287255032753e-05, 2.795419576483144e-05, 2.7236027934238183e-05, 2.6546586816868657e-05, 2.5884723344193908e-05, 2.524933441042615e-05, 2.4639361034009105e-05, 2.405378659264874e-05, 2.349163512894279e-05, 2.295196972378508e-05, 2.2433890934833674e-05, 2.1936535297440327e-05, 2.1459073885542716e-05, 2.1000710930121005e-05, 2.0560682492916165e-05, 2.0138255193199518e-05, 1.973272498547154e-05, 1.9343415986052673e-05, 1.896967934661057e-05, 1.8610892172746145e-05, 1.8266456485836298e-05, 1.7935798226402847e-05, 1.7618366297346733e-05, 1.7313631645452863e-05, 1.7021086379634746e-05, 1.6740242924449357e-05, 1.6470633207471384e-05, 1.6211807879172527e-05, 1.596333556400563e-05, 1.5724802141445403e-05, 1.5495810055787584e-05, 1.527597765355608e-05, 1.5064938547413839e-05, 1.4862341005517285e-05, 1.4667847365296593e-05, 1.448113347068473e-05, 1.430188813185734e-05, 1.4129812606583046e-05, 1.3964620102319723e-05, 1.3806035298226935e-05, 1.3653793886297858e-05, 1.3507642130845944e-05, 1.3367336445612106e-05, 1.3232642987787622e-05, 1.3103337268276115e-05, 1.297920377754507e-05, 1.2860035626443268e-05, 1.2745634201385537e-05, 1.2635808833330116e-05, 1.253037647999691e-05, 1.2429161420797035e-05, 1.2331994963965153e-05, 1.2238715165406547e-05, 1.2149166558790286e-05, 1.2063199896438674e-05, 1.1980671900581126e-05, 1.1901445024557881e-05, 1.1825387223575566e-05, 1.1752371734632544e-05, 1.1682276865247241e-05]

# %%
# Checkpoint
def set_cp(file = 'best.hdf5', monitor = 'val_loss', verbosity = 1, monitor_mode = 'auto', only_weights = True, best_only = True):
    global cp_callback

    cp_callback = keras.callbacks.ModelCheckpoint(filepath = save_path + 'best-{val_truncated_accuracy:.6f}.hdf5',
                                                monitor = monitor,
                                                verbose = verbosity,
                                                mode= monitor_mode, 
                                                save_weights_only = only_weights, 
                                                save_best_only = best_only)

set_cp(monitor = 'val_truncated_accuracy', only_weights=False)

# %% [markdown]
# ## Train

# %%
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy', #https://github.com/LucaAngioloni/ProteinSecondaryStructure-CNN/blob/master/dataset.py
              sample_weight_mode='temporal',
              metrics=[truncated_accuracy, 'accuracy','mae'])

# %%
trainX = np.load('/content/training-needs/trainX.npy')
print(trainX.shape)
# Out:
# (10029, 700, 57)

# %%
trainY = np.load('/content/training-needs/trainY.npy')[:,:,:8]
print(trainY.shape)
# Out:
# (10029, 700, 8)

# %%
trainAttm = np.load('/content/training-needs/trainAttM.npy')
print(trainAttm.shape)
# Out:
# (10029, 700)

# %%
trainPosIds = np.array(range(700))
trainPosIds = np.repeat([trainPosIds], int(trainX.shape[0]), axis=0)
print(trainPosIds.shape)
# Out:
# (10029, 700)

# %%
validationX = np.load('/content/training-needs/validationX.npy')
print(validationX.shape)
validationY = np.load('/content//training-needs/validationY.npy')[:,:,:8]
print(validationY.shape)
validationAttm = np.load('/content/training-needs/validationAttM.npy')
print(validationAttm.shape)
validationPosIds = np.array(range(700))
validationPosIds = np.repeat([validationPosIds], int(validationX.shape[0]), axis=0)
print(validationPosIds.shape)
# Out:
# (983, 700, 57)
# (983, 700, 8)
# (983, 700)
# (983, 700)

# %%
# sumX = np.sum(trainX[:,:,-7:],axis = -1)
del sumX

# %%
newTrainX = np.zeros((trainX.shape[0],trainX.shape[1],71), dtype = np.float32)
newTrainX[:,:,:50] = trainX[:,:,:50]

# %%
newValidationX = np.zeros((validationX.shape[0],validationX.shape[1],71), dtype = np.float32)
newValidationX[:,:,:50] = validationX[:,:,:50]

# %%
ddict = {-4.699254482240523: 1, 
         -2.659240181599653: 2, 
         3.3296421241715946: 3, 
         5.831546761482116: 4, 
         5.173050502506057: 5, 
         -9.417817513182396: 6, 
         2.743641270452359: 7, 
         -2.745201910872933: 8, 
         3.7126031557225985: 9, 
         -0.6267770318005056: 10, 
         3.657603823993523: 11, 
         4.538166821953532: 12, 
         -2.1242114975143718: 13, 
         5.814161339545225: 14, 
         1.9629522760351774: 15, 
         -5.770085388176039: 16, 
         -3.544985138554951: 17, 
         -0.7043947065506566: 18, 
         0.014481430079892332: 19, 
         9.879889365399787: 20, 
         0.0: 0}

# %%
for i in range(trainX.shape[0]):
  for j in range(700):
    summ = np.sum(trainX[i,j,50:])
    if summ in ddict.keys():
      newTrainX[i,j,ddict[summ]] = 1
    else:
      print('fuck')

for i in range(validationX.shape[0]):
  for j in range(700):
    summ = np.sum(validationX[i,j,50:])
    if summ in ddict.keys():
      newValidationX[i,j,ddict[summ]] = 1
    else:
      print('fuck')

# %%
trainX = newTrainX
validationX = newValidationX

# %%
# checkk = {}
# for i in range(sumX.shape[0]):
#   for j in range(700):
#     if sumX[i,j] not in checkk.keys():
#       checkk[sumX[i,j]] = 1
# print(len(checkk))
# print(checkk)
# Out:
# 21
# {-4.699254482240523: 1, -2.659240181599653: 1, 3.3296421241715946: 1, 5.831546761482116: 1, 5.173050502506057: 1, -9.417817513182396: 1, 2.743641270452359: 1, -2.745201910872933: 1, 3.7126031557225985: 1, -0.6267770318005056: 1, 3.657603823993523: 1, 4.538166821953532: 1, -2.1242114975143718: 1, 5.814161339545225: 1, 1.9629522760351774: 1, -5.770085388176039: 1, -3.544985138554951: 1, -0.7043947065506566: 1, 0.014481430079892332: 1, 9.879889365399787: 1, 0.0: 1}

# %%
# sumX = np.sum(validationX[:,:,-7:],axis = -1)
# checkk = {}
# for i in range(sumX.shape[0]):
#   for j in range(700):
#     if sumX[i,j] not in checkk.keys():
#       checkk[sumX[i,j]] = 1
# print(len(checkk))
# print(checkk)
# Out:
# 21
# {-3.544985138554951: 1, -2.745201910872933: 1, 1.9629522760351774: 1, -0.6267770318005056: 1, 5.831546761482116: 1, 3.7126031557225985: 1, 2.743641270452359: 1, -2.659240181599653: 1, 3.657603823993523: 1, 5.173050502506057: 1, -5.770085388176039: 1, -4.699254482240523: 1, -2.1242114975143718: 1, 4.538166821953532: 1, 5.814161339545225: 1, -0.7043947065506566: 1, -9.417817513182396: 1, 0.0: 1, 3.3296421241715946: 1, 9.879889365399787: 1, 0.014481430079892332: 1}

# %%
trainX = np.float32(trainX)
trainAttm = np.float32(trainAttm)
trainPosIds = np.float32(trainPosIds)
trainY = np.int32(trainY)
validationX = np.float32(validationX)
validationAttm = np.float32(validationAttm)
validationPosIds = np.float32(validationPosIds)
validationY = np.int32(validationY)

# %%
print(keras.backend.floatx())
# Out:
# float32

# %%
total_epochs = 150

# %%
## run1
history = model.fit(
    x=[trainX,trainAttm,trainPosIds],
    y=trainY,
    batch_size=20,
    epochs=total_epochs,
    verbose=1,
    validation_data=([validationX,validationAttm,validationPosIds],validationY),
    # validation_batch_size = 8,
    shuffle=True,
    workers = -1,
    callbacks=[lr_callback, es_callback, cp_callback]
)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 10029 samples, validate on 983 samples
# Epoch 1/150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-07.
# 10029/10029 [==============================] - 384s 38ms/step - loss: 12.7344 - truncated_accuracy: 0.0914 - accuracy: 0.0749 - mae: 0.1566 - val_loss: 12.5886 - val_truncated_accuracy: 0.0821 - val_accuracy: 0.0594 - val_mae: 0.1559
#
# Epoch 00001: val_truncated_accuracy improved from -inf to 0.08206, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.082063.hdf5
# Epoch 2/150
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 5.009000000000001e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 11.1350 - truncated_accuracy: 0.3305 - accuracy: 0.1369 - mae: 0.1440 - val_loss: 9.8037 - val_truncated_accuracy: 0.5255 - val_accuracy: 0.1812 - val_mae: 0.1307
#
# Epoch 00002: val_truncated_accuracy improved from 0.08206 to 0.52549, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.525486.hdf5
# Epoch 3/150
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.00010008000000000002.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 7.8749 - truncated_accuracy: 0.5842 - accuracy: 0.2789 - mae: 0.1263 - val_loss: 6.2137 - val_truncated_accuracy: 0.6289 - val_accuracy: 0.2967 - val_mae: 0.1230
#
# Epoch 00003: val_truncated_accuracy improved from 0.52549 to 0.62891, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.628906.hdf5
# Epoch 4/150
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00015007000000000003.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 4.5974 - truncated_accuracy: 0.6548 - accuracy: 0.3405 - mae: 0.1211 - val_loss: 3.3204 - val_truncated_accuracy: 0.6741 - val_accuracy: 0.2979 - val_mae: 0.1217
#
# Epoch 00004: val_truncated_accuracy improved from 0.62891 to 0.67409, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.674095.hdf5
# Epoch 5/150
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.00020006000000000003.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 2.3459 - truncated_accuracy: 0.6833 - accuracy: 0.3559 - mae: 0.1185 - val_loss: 1.6300 - val_truncated_accuracy: 0.6719 - val_accuracy: 0.3353 - val_mae: 0.1214
#
# Epoch 00005: val_truncated_accuracy did not improve from 0.67409
# Epoch 6/150
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.00025005000000000003.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 1.1349 - truncated_accuracy: 0.7002 - accuracy: 0.3778 - mae: 0.1169 - val_loss: 0.7937 - val_truncated_accuracy: 0.6984 - val_accuracy: 0.3588 - val_mae: 0.1193
#
# Epoch 00006: val_truncated_accuracy improved from 0.67409 to 0.69841, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.698406.hdf5
# Epoch 7/150
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.00030004000000000006.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.5914 - truncated_accuracy: 0.7098 - accuracy: 0.3649 - mae: 0.1160 - val_loss: 0.4451 - val_truncated_accuracy: 0.7182 - val_accuracy: 0.2960 - val_mae: 0.1171
#
# Epoch 00007: val_truncated_accuracy improved from 0.69841 to 0.71817, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.718174.hdf5
# Epoch 8/150
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.00035003000000000004.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3834 - truncated_accuracy: 0.7137 - accuracy: 0.3487 - mae: 0.1157 - val_loss: 0.3236 - val_truncated_accuracy: 0.7221 - val_accuracy: 0.3635 - val_mae: 0.1156
#
# Epoch 00008: val_truncated_accuracy improved from 0.71817 to 0.72210, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.722096.hdf5
# Epoch 9/150
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.00040002000000000006.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3217 - truncated_accuracy: 0.7154 - accuracy: 0.3704 - mae: 0.1156 - val_loss: 0.3067 - val_truncated_accuracy: 0.7154 - val_accuracy: 0.3603 - val_mae: 0.1172
#
# Epoch 00009: val_truncated_accuracy did not improve from 0.72210
# Epoch 10/150
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0004500100000000001.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3097 - truncated_accuracy: 0.7161 - accuracy: 0.3735 - mae: 0.1156 - val_loss: 0.2984 - val_truncated_accuracy: 0.7213 - val_accuracy: 0.3625 - val_mae: 0.1163
#
# Epoch 00010: val_truncated_accuracy did not improve from 0.72210
# Epoch 11/150
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0005.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3222 - truncated_accuracy: 0.7139 - accuracy: 0.3806 - mae: 0.1157 - val_loss: 0.3430 - val_truncated_accuracy: 0.6817 - val_accuracy: 0.3305 - val_mae: 0.1204
#
# Epoch 00011: val_truncated_accuracy did not improve from 0.72210
# Epoch 12/150
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.00048039999999999997.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3117 - truncated_accuracy: 0.7162 - accuracy: 0.4295 - mae: 0.1155 - val_loss: 0.3223 - val_truncated_accuracy: 0.7057 - val_accuracy: 0.5008 - val_mae: 0.1181
#
# Epoch 00012: val_truncated_accuracy did not improve from 0.72210
# Epoch 13/150
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.000461584.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3078 - truncated_accuracy: 0.7182 - accuracy: 0.4467 - mae: 0.1153 - val_loss: 0.3097 - val_truncated_accuracy: 0.7095 - val_accuracy: 0.4097 - val_mae: 0.1172
#
# Epoch 00013: val_truncated_accuracy did not improve from 0.72210
# Epoch 14/150
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0004435206399999999.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3241 - truncated_accuracy: 0.7186 - accuracy: 0.4391 - mae: 0.1153 - val_loss: 0.3338 - val_truncated_accuracy: 0.7226 - val_accuracy: 0.5036 - val_mae: 0.1140
#
# Epoch 00014: val_truncated_accuracy improved from 0.72210 to 0.72259, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.722593.hdf5
# Epoch 15/150
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.00042617981439999997.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3206 - truncated_accuracy: 0.7203 - accuracy: 0.4493 - mae: 0.1151 - val_loss: 0.3598 - val_truncated_accuracy: 0.6710 - val_accuracy: 0.6513 - val_mae: 0.1229
#
# Epoch 00015: val_truncated_accuracy did not improve from 0.72259
# Epoch 16/150
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.00040953262182399995.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3154 - truncated_accuracy: 0.7209 - accuracy: 0.4332 - mae: 0.1151 - val_loss: 0.3008 - val_truncated_accuracy: 0.7217 - val_accuracy: 0.4300 - val_mae: 0.1167
#
# Epoch 00016: val_truncated_accuracy did not improve from 0.72259
# Epoch 17/150
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0003935513169510399.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3096 - truncated_accuracy: 0.7224 - accuracy: 0.4692 - mae: 0.1149 - val_loss: 0.3275 - val_truncated_accuracy: 0.7106 - val_accuracy: 0.4000 - val_mae: 0.1163
#
# Epoch 00017: val_truncated_accuracy did not improve from 0.72259
# Epoch 18/150
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0003782092642729983.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.3335 - truncated_accuracy: 0.7205 - accuracy: 0.4668 - mae: 0.1151 - val_loss: 0.3720 - val_truncated_accuracy: 0.7152 - val_accuracy: 0.5616 - val_mae: 0.1144
#
# Epoch 00018: val_truncated_accuracy did not improve from 0.72259
# Epoch 19/150
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0003634808937020784.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.3474 - truncated_accuracy: 0.7226 - accuracy: 0.4623 - mae: 0.1149 - val_loss: 0.3181 - val_truncated_accuracy: 0.7220 - val_accuracy: 0.4258 - val_mae: 0.1184
#
# Epoch 00019: val_truncated_accuracy did not improve from 0.72259
# Epoch 20/150
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.00034934165795399524.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.3536 - truncated_accuracy: 0.7173 - accuracy: 0.4691 - mae: 0.1154 - val_loss: 0.3366 - val_truncated_accuracy: 0.7172 - val_accuracy: 0.3390 - val_mae: 0.1186
#
# Epoch 00020: val_truncated_accuracy did not improve from 0.72259
# Epoch 21/150
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0003357679916358354.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.3136 - truncated_accuracy: 0.7255 - accuracy: 0.4752 - mae: 0.1146 - val_loss: 0.3026 - val_truncated_accuracy: 0.7233 - val_accuracy: 0.3895 - val_mae: 0.1144
#
# Epoch 00021: val_truncated_accuracy improved from 0.72259 to 0.72329, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.723285.hdf5
# Epoch 22/150
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.000322737271970402.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3132 - truncated_accuracy: 0.7277 - accuracy: 0.4708 - mae: 0.1144 - val_loss: 0.3083 - val_truncated_accuracy: 0.7329 - val_accuracy: 0.5294 - val_mae: 0.1149
#
# Epoch 00022: val_truncated_accuracy improved from 0.72329 to 0.73291, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.732907.hdf5
# Epoch 23/150
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0003102277810915859.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3074 - truncated_accuracy: 0.7293 - accuracy: 0.4779 - mae: 0.1143 - val_loss: 0.3445 - val_truncated_accuracy: 0.6861 - val_accuracy: 0.2418 - val_mae: 0.1204
#
# Epoch 00023: val_truncated_accuracy did not improve from 0.73291
# Epoch 24/150
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.00029821866984792246.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2970 - truncated_accuracy: 0.7301 - accuracy: 0.4691 - mae: 0.1142 - val_loss: 0.2922 - val_truncated_accuracy: 0.7238 - val_accuracy: 0.3442 - val_mae: 0.1135
#
# Epoch 00024: val_truncated_accuracy did not improve from 0.73291
# Epoch 25/150
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.00028668992305400554.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2900 - truncated_accuracy: 0.7311 - accuracy: 0.4939 - mae: 0.1141 - val_loss: 0.2843 - val_truncated_accuracy: 0.7353 - val_accuracy: 0.3956 - val_mae: 0.1141
#
# Epoch 00025: val_truncated_accuracy improved from 0.73291 to 0.73525, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.735254.hdf5
# Epoch 26/150
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0002756223261318453.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2923 - truncated_accuracy: 0.7325 - accuracy: 0.4866 - mae: 0.1139 - val_loss: 0.3068 - val_truncated_accuracy: 0.7206 - val_accuracy: 0.2802 - val_mae: 0.1147
#
# Epoch 00026: val_truncated_accuracy did not improve from 0.73525
# Epoch 27/150
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0002649974330865715.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.3065 - truncated_accuracy: 0.7324 - accuracy: 0.4893 - mae: 0.1140 - val_loss: 0.3036 - val_truncated_accuracy: 0.7273 - val_accuracy: 0.5793 - val_mae: 0.1143
#
# Epoch 00027: val_truncated_accuracy did not improve from 0.73525
# Epoch 28/150
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0002547975357631086.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2913 - truncated_accuracy: 0.7348 - accuracy: 0.4945 - mae: 0.1137 - val_loss: 0.2822 - val_truncated_accuracy: 0.7376 - val_accuracy: 0.4792 - val_mae: 0.1135
#
# Epoch 00028: val_truncated_accuracy improved from 0.73525 to 0.73757, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.737567.hdf5
# Epoch 29/150
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.00024500563433258425.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2782 - truncated_accuracy: 0.7367 - accuracy: 0.5048 - mae: 0.1135 - val_loss: 0.2667 - val_truncated_accuracy: 0.7382 - val_accuracy: 0.3762 - val_mae: 0.1137
#
# Epoch 00029: val_truncated_accuracy improved from 0.73757 to 0.73823, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.738227.hdf5
# Epoch 30/150
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.00023560540895928086.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2832 - truncated_accuracy: 0.7363 - accuracy: 0.4980 - mae: 0.1136 - val_loss: 0.2871 - val_truncated_accuracy: 0.7291 - val_accuracy: 0.2942 - val_mae: 0.1142
#
# Epoch 00030: val_truncated_accuracy did not improve from 0.73823
# Epoch 31/150
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.00022658119260090962.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2766 - truncated_accuracy: 0.7379 - accuracy: 0.4947 - mae: 0.1134 - val_loss: 1.4025 - val_truncated_accuracy: 0.2476 - val_accuracy: 0.0813 - val_mae: 0.1439
#
# Epoch 00031: val_truncated_accuracy did not improve from 0.73823
# Epoch 32/150
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0002179179448968732.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2776 - truncated_accuracy: 0.7387 - accuracy: 0.4871 - mae: 0.1133 - val_loss: 0.2734 - val_truncated_accuracy: 0.7386 - val_accuracy: 0.4672 - val_mae: 0.1129
#
# Epoch 00032: val_truncated_accuracy improved from 0.73823 to 0.73862, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.738624.hdf5
# Epoch 33/150
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.00020960122710099829.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2793 - truncated_accuracy: 0.7398 - accuracy: 0.4807 - mae: 0.1133 - val_loss: 0.2722 - val_truncated_accuracy: 0.7406 - val_accuracy: 0.4335 - val_mae: 0.1137
#
# Epoch 00033: val_truncated_accuracy improved from 0.73862 to 0.74061, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.740606.hdf5
# Epoch 34/150
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.00020161717801695834.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2733 - truncated_accuracy: 0.7404 - accuracy: 0.4892 - mae: 0.1131 - val_loss: 0.2673 - val_truncated_accuracy: 0.7424 - val_accuracy: 0.4830 - val_mae: 0.1136
#
# Epoch 00034: val_truncated_accuracy improved from 0.74061 to 0.74236, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.742363.hdf5
# Epoch 35/150
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.00019395249089628.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2678 - truncated_accuracy: 0.7421 - accuracy: 0.5136 - mae: 0.1130 - val_loss: 0.2622 - val_truncated_accuracy: 0.7433 - val_accuracy: 0.4082 - val_mae: 0.1132
#
# Epoch 00035: val_truncated_accuracy improved from 0.74236 to 0.74327, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.743268.hdf5
# Epoch 36/150
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0001865943912604288.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2669 - truncated_accuracy: 0.7428 - accuracy: 0.4999 - mae: 0.1129 - val_loss: 0.2588 - val_truncated_accuracy: 0.7417 - val_accuracy: 0.4210 - val_mae: 0.1131
#
# Epoch 00036: val_truncated_accuracy did not improve from 0.74327
# Epoch 37/150
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.00017953061561001163.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2644 - truncated_accuracy: 0.7441 - accuracy: 0.4780 - mae: 0.1128 - val_loss: 0.2614 - val_truncated_accuracy: 0.7448 - val_accuracy: 0.4051 - val_mae: 0.1128
#
# Epoch 00037: val_truncated_accuracy improved from 0.74327 to 0.74479, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.744785.hdf5
# Epoch 38/150
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0001727493909856112.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2625 - truncated_accuracy: 0.7448 - accuracy: 0.5063 - mae: 0.1127 - val_loss: 0.2562 - val_truncated_accuracy: 0.7444 - val_accuracy: 0.4740 - val_mae: 0.1125
#
# Epoch 00038: val_truncated_accuracy did not improve from 0.74479
# Epoch 39/150
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.00016623941534618672.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2585 - truncated_accuracy: 0.7453 - accuracy: 0.5035 - mae: 0.1127 - val_loss: 0.2540 - val_truncated_accuracy: 0.7442 - val_accuracy: 0.4803 - val_mae: 0.1128
#
# Epoch 00039: val_truncated_accuracy did not improve from 0.74479
# Epoch 40/150
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.00015998983873233925.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2539 - truncated_accuracy: 0.7465 - accuracy: 0.4871 - mae: 0.1125 - val_loss: 0.2489 - val_truncated_accuracy: 0.7450 - val_accuracy: 0.4197 - val_mae: 0.1119
#
# Epoch 00040: val_truncated_accuracy improved from 0.74479 to 0.74500, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.745003.hdf5
# Epoch 41/150
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00015399024518304567.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2594 - truncated_accuracy: 0.7469 - accuracy: 0.4989 - mae: 0.1125 - val_loss: 0.2544 - val_truncated_accuracy: 0.7473 - val_accuracy: 0.5065 - val_mae: 0.1124
#
# Epoch 00041: val_truncated_accuracy improved from 0.74500 to 0.74728, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.747277.hdf5
# Epoch 42/150
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.00014823063537572386.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2610 - truncated_accuracy: 0.7477 - accuracy: 0.4868 - mae: 0.1124 - val_loss: 0.2570 - val_truncated_accuracy: 0.7458 - val_accuracy: 0.4956 - val_mae: 0.1119
#
# Epoch 00042: val_truncated_accuracy did not improve from 0.74728
# Epoch 43/150
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.00014270140996069488.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2548 - truncated_accuracy: 0.7489 - accuracy: 0.5105 - mae: 0.1123 - val_loss: 0.2465 - val_truncated_accuracy: 0.7475 - val_accuracy: 0.3855 - val_mae: 0.1124
#
# Epoch 00043: val_truncated_accuracy improved from 0.74728 to 0.74746, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.747456.hdf5
# Epoch 44/150
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0001373933535622671.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2529 - truncated_accuracy: 0.7491 - accuracy: 0.5075 - mae: 0.1123 - val_loss: 0.2502 - val_truncated_accuracy: 0.7450 - val_accuracy: 0.4605 - val_mae: 0.1120
#
# Epoch 00044: val_truncated_accuracy did not improve from 0.74746
# Epoch 45/150
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0001322976194197764.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2488 - truncated_accuracy: 0.7506 - accuracy: 0.5046 - mae: 0.1121 - val_loss: 0.2445 - val_truncated_accuracy: 0.7477 - val_accuracy: 0.4513 - val_mae: 0.1118
#
# Epoch 00045: val_truncated_accuracy improved from 0.74746 to 0.74771, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.747713.hdf5
# Epoch 46/150
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.00012740571464298534.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2458 - truncated_accuracy: 0.7510 - accuracy: 0.4949 - mae: 0.1121 - val_loss: 0.2424 - val_truncated_accuracy: 0.7488 - val_accuracy: 0.4901 - val_mae: 0.1121
#
# Epoch 00046: val_truncated_accuracy improved from 0.74771 to 0.74884, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.748842.hdf5
# Epoch 47/150
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.00012270948605726592.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2454 - truncated_accuracy: 0.7519 - accuracy: 0.5180 - mae: 0.1120 - val_loss: 0.2433 - val_truncated_accuracy: 0.7488 - val_accuracy: 0.4631 - val_mae: 0.1119
#
# Epoch 00047: val_truncated_accuracy did not improve from 0.74884
# Epoch 48/150
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.00011820110661497527.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2433 - truncated_accuracy: 0.7529 - accuracy: 0.5034 - mae: 0.1119 - val_loss: 0.2458 - val_truncated_accuracy: 0.7424 - val_accuracy: 0.5796 - val_mae: 0.1125
#
# Epoch 00048: val_truncated_accuracy did not improve from 0.74884
# Epoch 49/150
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.00011387306235037627.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2472 - truncated_accuracy: 0.7527 - accuracy: 0.5045 - mae: 0.1119 - val_loss: 0.2510 - val_truncated_accuracy: 0.7470 - val_accuracy: 0.4778 - val_mae: 0.1118
#
# Epoch 00049: val_truncated_accuracy did not improve from 0.74884
# Epoch 50/150
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0001097181398563612.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2461 - truncated_accuracy: 0.7542 - accuracy: 0.4951 - mae: 0.1118 - val_loss: 0.2427 - val_truncated_accuracy: 0.7501 - val_accuracy: 0.4371 - val_mae: 0.1115
#
# Epoch 00050: val_truncated_accuracy improved from 0.74884 to 0.75011, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.750115.hdf5
# Epoch 51/150
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.00010572941426210676.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2421 - truncated_accuracy: 0.7547 - accuracy: 0.4995 - mae: 0.1117 - val_loss: 0.2393 - val_truncated_accuracy: 0.7525 - val_accuracy: 0.4565 - val_mae: 0.1119
#
# Epoch 00051: val_truncated_accuracy improved from 0.75011 to 0.75248, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.752477.hdf5
# Epoch 52/150
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.00010190023769162248.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2411 - truncated_accuracy: 0.7553 - accuracy: 0.5074 - mae: 0.1117 - val_loss: 0.2716 - val_truncated_accuracy: 0.7260 - val_accuracy: 0.8410 - val_mae: 0.1145
#
# Epoch 00052: val_truncated_accuracy did not improve from 0.75248
# Epoch 53/150
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 9.822422818395758e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2430 - truncated_accuracy: 0.7559 - accuracy: 0.5118 - mae: 0.1116 - val_loss: 0.2410 - val_truncated_accuracy: 0.7525 - val_accuracy: 0.5105 - val_mae: 0.1115
#
# Epoch 00053: val_truncated_accuracy improved from 0.75248 to 0.75254, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.752535.hdf5
# Epoch 54/150
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 9.469525905659927e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2401 - truncated_accuracy: 0.7567 - accuracy: 0.5122 - mae: 0.1115 - val_loss: 0.2382 - val_truncated_accuracy: 0.7528 - val_accuracy: 0.4950 - val_mae: 0.1111
#
# Epoch 00054: val_truncated_accuracy improved from 0.75254 to 0.75283, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.752829.hdf5
# Epoch 55/150
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 9.13074486943353e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2395 - truncated_accuracy: 0.7574 - accuracy: 0.5001 - mae: 0.1115 - val_loss: 0.2410 - val_truncated_accuracy: 0.7523 - val_accuracy: 0.4933 - val_mae: 0.1116
#
# Epoch 00055: val_truncated_accuracy did not improve from 0.75283
# Epoch 56/150
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 8.805515074656189e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2394 - truncated_accuracy: 0.7577 - accuracy: 0.4989 - mae: 0.1114 - val_loss: 0.2378 - val_truncated_accuracy: 0.7527 - val_accuracy: 0.4825 - val_mae: 0.1112
#
# Epoch 00056: val_truncated_accuracy did not improve from 0.75283
# Epoch 57/150
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 8.49329447166994e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2365 - truncated_accuracy: 0.7587 - accuracy: 0.5081 - mae: 0.1113 - val_loss: 0.2375 - val_truncated_accuracy: 0.7524 - val_accuracy: 0.4450 - val_mae: 0.1112
#
# Epoch 00057: val_truncated_accuracy did not improve from 0.75283
# Epoch 58/150
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 8.193562692803143e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2339 - truncated_accuracy: 0.7593 - accuracy: 0.5061 - mae: 0.1113 - val_loss: 0.2338 - val_truncated_accuracy: 0.7540 - val_accuracy: 0.4903 - val_mae: 0.1112
#
# Epoch 00058: val_truncated_accuracy improved from 0.75283 to 0.75404, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.754039.hdf5
# Epoch 59/150
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 7.905820185091017e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2325 - truncated_accuracy: 0.7597 - accuracy: 0.5103 - mae: 0.1112 - val_loss: 0.2339 - val_truncated_accuracy: 0.7539 - val_accuracy: 0.5587 - val_mae: 0.1112
#
# Epoch 00059: val_truncated_accuracy did not improve from 0.75404
# Epoch 60/150
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 7.629587377687376e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2313 - truncated_accuracy: 0.7609 - accuracy: 0.5222 - mae: 0.1111 - val_loss: 0.2380 - val_truncated_accuracy: 0.7505 - val_accuracy: 0.6939 - val_mae: 0.1113
#
# Epoch 00060: val_truncated_accuracy did not improve from 0.75404
# Epoch 61/150
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 7.36440388257988e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2335 - truncated_accuracy: 0.7607 - accuracy: 0.5183 - mae: 0.1111 - val_loss: 0.2374 - val_truncated_accuracy: 0.7536 - val_accuracy: 0.5052 - val_mae: 0.1109
#
# Epoch 00061: val_truncated_accuracy did not improve from 0.75404
# Epoch 62/150
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 7.109827727276686e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2329 - truncated_accuracy: 0.7617 - accuracy: 0.5125 - mae: 0.1110 - val_loss: 0.2361 - val_truncated_accuracy: 0.7541 - val_accuracy: 0.4549 - val_mae: 0.1108
#
# Epoch 00062: val_truncated_accuracy improved from 0.75404 to 0.75411, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.754109.hdf5
# Epoch 63/150
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 6.865434618185618e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2311 - truncated_accuracy: 0.7624 - accuracy: 0.5164 - mae: 0.1110 - val_loss: 0.2332 - val_truncated_accuracy: 0.7547 - val_accuracy: 0.4799 - val_mae: 0.1109
#
# Epoch 00063: val_truncated_accuracy improved from 0.75411 to 0.75471, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.754711.hdf5
# Epoch 64/150
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 6.630817233458192e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2291 - truncated_accuracy: 0.7631 - accuracy: 0.5200 - mae: 0.1109 - val_loss: 0.2335 - val_truncated_accuracy: 0.7539 - val_accuracy: 0.5039 - val_mae: 0.1110
#
# Epoch 00064: val_truncated_accuracy did not improve from 0.75471
# Epoch 65/150
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 6.405584544119865e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2281 - truncated_accuracy: 0.7632 - accuracy: 0.5132 - mae: 0.1109 - val_loss: 0.2315 - val_truncated_accuracy: 0.7546 - val_accuracy: 0.5181 - val_mae: 0.1108
#
# Epoch 00065: val_truncated_accuracy did not improve from 0.75471
# Epoch 66/150
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 6.18936116235507e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2273 - truncated_accuracy: 0.7641 - accuracy: 0.5102 - mae: 0.1108 - val_loss: 0.2319 - val_truncated_accuracy: 0.7562 - val_accuracy: 0.4362 - val_mae: 0.1108
#
# Epoch 00066: val_truncated_accuracy improved from 0.75471 to 0.75615, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.756151.hdf5
# Epoch 67/150
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 5.981786715860867e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2267 - truncated_accuracy: 0.7646 - accuracy: 0.5145 - mae: 0.1107 - val_loss: 0.2329 - val_truncated_accuracy: 0.7554 - val_accuracy: 0.5369 - val_mae: 0.1106
#
# Epoch 00067: val_truncated_accuracy did not improve from 0.75615
# Epoch 68/150
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 5.7825152472264316e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2274 - truncated_accuracy: 0.7649 - accuracy: 0.5143 - mae: 0.1107 - val_loss: 0.2326 - val_truncated_accuracy: 0.7556 - val_accuracy: 0.4659 - val_mae: 0.1110
#
# Epoch 00068: val_truncated_accuracy did not improve from 0.75615
# Epoch 69/150
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 5.5912146373373745e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2275 - truncated_accuracy: 0.7653 - accuracy: 0.5141 - mae: 0.1107 - val_loss: 0.2341 - val_truncated_accuracy: 0.7555 - val_accuracy: 0.5329 - val_mae: 0.1104
#
# Epoch 00069: val_truncated_accuracy did not improve from 0.75615
# Epoch 70/150
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 5.407566051843879e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2277 - truncated_accuracy: 0.7660 - accuracy: 0.5169 - mae: 0.1106 - val_loss: 0.2347 - val_truncated_accuracy: 0.7558 - val_accuracy: 0.5028 - val_mae: 0.1108
#
# Epoch 00070: val_truncated_accuracy did not improve from 0.75615
# Epoch 71/150
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 5.231263409770124e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2280 - truncated_accuracy: 0.7662 - accuracy: 0.5145 - mae: 0.1106 - val_loss: 0.2346 - val_truncated_accuracy: 0.7561 - val_accuracy: 0.4451 - val_mae: 0.1105
#
# Epoch 00071: val_truncated_accuracy did not improve from 0.75615
# Epoch 72/150
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 5.0620128733793184e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2261 - truncated_accuracy: 0.7672 - accuracy: 0.5054 - mae: 0.1105 - val_loss: 0.2326 - val_truncated_accuracy: 0.7561 - val_accuracy: 0.4691 - val_mae: 0.1106
#
# Epoch 00072: val_truncated_accuracy did not improve from 0.75615
# Epoch 73/150
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 4.8995323584441456e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2242 - truncated_accuracy: 0.7676 - accuracy: 0.5142 - mae: 0.1104 - val_loss: 0.2309 - val_truncated_accuracy: 0.7559 - val_accuracy: 0.4694 - val_mae: 0.1106
#
# Epoch 00073: val_truncated_accuracy did not improve from 0.75615
# Epoch 74/150
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 4.74355106410638e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2223 - truncated_accuracy: 0.7680 - accuracy: 0.5062 - mae: 0.1104 - val_loss: 0.2301 - val_truncated_accuracy: 0.7564 - val_accuracy: 0.5385 - val_mae: 0.1105
#
# Epoch 00074: val_truncated_accuracy improved from 0.75615 to 0.75640, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.756403.hdf5
# Epoch 75/150
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 4.593809021542125e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2211 - truncated_accuracy: 0.7683 - accuracy: 0.5160 - mae: 0.1103 - val_loss: 0.2306 - val_truncated_accuracy: 0.7555 - val_accuracy: 0.5150 - val_mae: 0.1103
#
# Epoch 00075: val_truncated_accuracy did not improve from 0.75640
# Epoch 76/150
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 4.4500566606804394e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2200 - truncated_accuracy: 0.7692 - accuracy: 0.5070 - mae: 0.1103 - val_loss: 0.2302 - val_truncated_accuracy: 0.7566 - val_accuracy: 0.5113 - val_mae: 0.1102
#
# Epoch 00076: val_truncated_accuracy improved from 0.75640 to 0.75658, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.756585.hdf5
# Epoch 77/150
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 4.312054394253222e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2189 - truncated_accuracy: 0.7695 - accuracy: 0.5097 - mae: 0.1102 - val_loss: 0.2294 - val_truncated_accuracy: 0.7559 - val_accuracy: 0.4896 - val_mae: 0.1103
#
# Epoch 00077: val_truncated_accuracy did not improve from 0.75658
# Epoch 78/150
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 4.179572218483093e-05.
# 10029/10029 [==============================] - 321s 32ms/step - loss: 0.2182 - truncated_accuracy: 0.7700 - accuracy: 0.4976 - mae: 0.1102 - val_loss: 0.2284 - val_truncated_accuracy: 0.7570 - val_accuracy: 0.4983 - val_mae: 0.1101
#
# Epoch 00078: val_truncated_accuracy improved from 0.75658 to 0.75704, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.757037.hdf5
# Epoch 79/150
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 4.0523893297437694e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2177 - truncated_accuracy: 0.7703 - accuracy: 0.4996 - mae: 0.1101 - val_loss: 0.2278 - val_truncated_accuracy: 0.7560 - val_accuracy: 0.4577 - val_mae: 0.1104
#
# Epoch 00079: val_truncated_accuracy did not improve from 0.75704
# Epoch 80/150
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 3.930293756554018e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2174 - truncated_accuracy: 0.7705 - accuracy: 0.5124 - mae: 0.1101 - val_loss: 0.2275 - val_truncated_accuracy: 0.7568 - val_accuracy: 0.5480 - val_mae: 0.1103
#
# Epoch 00080: val_truncated_accuracy did not improve from 0.75704
# Epoch 81/150
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 3.8130820062918575e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2165 - truncated_accuracy: 0.7713 - accuracy: 0.5165 - mae: 0.1100 - val_loss: 0.2267 - val_truncated_accuracy: 0.7572 - val_accuracy: 0.5208 - val_mae: 0.1104
#
# Epoch 00081: val_truncated_accuracy improved from 0.75704 to 0.75724, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.757245.hdf5
# Epoch 82/150
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 3.700558726040183e-05.
# 10029/10029 [==============================] - 322s 32ms/step - loss: 0.2158 - truncated_accuracy: 0.7716 - accuracy: 0.5087 - mae: 0.1100 - val_loss: 0.2278 - val_truncated_accuracy: 0.7571 - val_accuracy: 0.5145 - val_mae: 0.1103
#
# Epoch 00082: val_truncated_accuracy did not improve from 0.75724
# Epoch 83/150
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 3.592536376998576e-05.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.2151 - truncated_accuracy: 0.7718 - accuracy: 0.5094 - mae: 0.1100 - val_loss: 0.2280 - val_truncated_accuracy: 0.7573 - val_accuracy: 0.4977 - val_mae: 0.1103
#
# Epoch 00083: val_truncated_accuracy improved from 0.75724 to 0.75733, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.757331.hdf5
# Epoch 84/150
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 3.4888349219186326e-05.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.2152 - truncated_accuracy: 0.7720 - accuracy: 0.5056 - mae: 0.1099 - val_loss: 0.2265 - val_truncated_accuracy: 0.7588 - val_accuracy: 0.5223 - val_mae: 0.1102
#
# Epoch 00084: val_truncated_accuracy improved from 0.75733 to 0.75877, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.758766.hdf5
# Epoch 85/150
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 3.389281525041887e-05.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.2147 - truncated_accuracy: 0.7728 - accuracy: 0.5179 - mae: 0.1099 - val_loss: 0.2271 - val_truncated_accuracy: 0.7577 - val_accuracy: 0.4911 - val_mae: 0.1102
#
# Epoch 00085: val_truncated_accuracy did not improve from 0.75877
# Epoch 86/150
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 3.293710264040212e-05.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.2139 - truncated_accuracy: 0.7731 - accuracy: 0.5175 - mae: 0.1099 - val_loss: 0.2262 - val_truncated_accuracy: 0.7581 - val_accuracy: 0.5378 - val_mae: 0.1101
#
# Epoch 00086: val_truncated_accuracy did not improve from 0.75877
# Epoch 87/150
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 3.201961853478603e-05.
# 10029/10029 [==============================] - 324s 32ms/step - loss: 0.2131 - truncated_accuracy: 0.7734 - accuracy: 0.5138 - mae: 0.1098 - val_loss: 0.2270 - val_truncated_accuracy: 0.7581 - val_accuracy: 0.5461 - val_mae: 0.1100
#
# Epoch 00087: val_truncated_accuracy did not improve from 0.75877
# Epoch 88/150
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 3.113883379339459e-05.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.2137 - truncated_accuracy: 0.7737 - accuracy: 0.5117 - mae: 0.1098 - val_loss: 0.2265 - val_truncated_accuracy: 0.7584 - val_accuracy: 0.4905 - val_mae: 0.1102
#
# Epoch 00088: val_truncated_accuracy did not improve from 0.75877
# Epoch 89/150
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 3.0293280441658803e-05.
# 10029/10029 [==============================] - 323s 32ms/step - loss: 0.2128 - truncated_accuracy: 0.7741 - accuracy: 0.5071 - mae: 0.1098 - val_loss: 0.2267 - val_truncated_accuracy: 0.7582 - val_accuracy: 0.4578 - val_mae: 0.1100
#
# Epoch 00089: val_truncated_accuracy did not improve from 0.75877
# Epoch 90/150
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 2.9481549223992448e-05.
# 10029/10029 [==============================] - 324s 32ms/step - loss: 0.2121 - truncated_accuracy: 0.7746 - accuracy: 0.5165 - mae: 0.1097 - val_loss: 0.2281 - val_truncated_accuracy: 0.7572 - val_accuracy: 0.5466 - val_mae: 0.1099
#
# Epoch 00090: val_truncated_accuracy did not improve from 0.75877
# Epoch 91/150
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 2.8702287255032753e-05.
#  7520/10029 [=====================>........] - ETA: 1:18 - loss: 0.2104 - truncated_accuracy: 0.7755 - accuracy: 0.5183 - mae: 0.1097

# %%
## run2
history = model.fit(
    x=[trainX,trainAttm,trainPosIds],
    y=trainY,
    batch_size=20,
    epochs=total_epochs,
    verbose=1,
    validation_data=([validationX,validationAttm,validationPosIds],validationY),
    # validation_batch_size = 8,
    shuffle=True,
    workers = -1,
    callbacks=[lr_callback, es_callback, cp_callback]
)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Train on 10029 samples, validate on 983 samples
# Epoch 1/150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 3.389281525041887e-05.
# 10029/10029 [==============================] - 406s 41ms/step - loss: 0.2145 - truncated_accuracy: 0.7727 - accuracy: 0.5127 - mae: 0.1099 - val_loss: 0.2262 - val_truncated_accuracy: 0.7578 - val_accuracy: 0.5035 - val_mae: 0.1102
#
# Epoch 00001: val_truncated_accuracy improved from -inf to 0.75777, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.757774.hdf5
# Epoch 2/150
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 3.293710264040212e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2136 - truncated_accuracy: 0.7733 - accuracy: 0.5181 - mae: 0.1099 - val_loss: 0.2253 - val_truncated_accuracy: 0.7588 - val_accuracy: 0.5156 - val_mae: 0.1102
#
# Epoch 00002: val_truncated_accuracy improved from 0.75777 to 0.75880, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.758797.hdf5
# Epoch 3/150
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 3.201961853478603e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2132 - truncated_accuracy: 0.7730 - accuracy: 0.5042 - mae: 0.1098 - val_loss: 0.2257 - val_truncated_accuracy: 0.7576 - val_accuracy: 0.4951 - val_mae: 0.1102
#
# Epoch 00003: val_truncated_accuracy did not improve from 0.75880
# Epoch 4/150
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 3.113883379339459e-05.
# 10029/10029 [==============================] - 333s 33ms/step - loss: 0.2128 - truncated_accuracy: 0.7736 - accuracy: 0.5023 - mae: 0.1098 - val_loss: 0.2265 - val_truncated_accuracy: 0.7584 - val_accuracy: 0.4875 - val_mae: 0.1100
#
# Epoch 00004: val_truncated_accuracy did not improve from 0.75880
# Epoch 5/150
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 3.0293280441658803e-05.
# 10029/10029 [==============================] - 333s 33ms/step - loss: 0.2124 - truncated_accuracy: 0.7741 - accuracy: 0.5124 - mae: 0.1098 - val_loss: 0.2260 - val_truncated_accuracy: 0.7579 - val_accuracy: 0.5100 - val_mae: 0.1101
#
# Epoch 00005: val_truncated_accuracy did not improve from 0.75880
# Epoch 6/150
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 2.9481549223992448e-05.
# 10029/10029 [==============================] - 333s 33ms/step - loss: 0.2123 - truncated_accuracy: 0.7741 - accuracy: 0.5082 - mae: 0.1097 - val_loss: 0.2264 - val_truncated_accuracy: 0.7591 - val_accuracy: 0.4894 - val_mae: 0.1099
#
# Epoch 00006: val_truncated_accuracy improved from 0.75880 to 0.75909, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.759093.hdf5
# Epoch 7/150
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 2.8702287255032753e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2117 - truncated_accuracy: 0.7747 - accuracy: 0.5075 - mae: 0.1097 - val_loss: 0.2249 - val_truncated_accuracy: 0.7589 - val_accuracy: 0.5024 - val_mae: 0.1102
#
# Epoch 00007: val_truncated_accuracy did not improve from 0.75909
# Epoch 8/150
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 2.795419576483144e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2112 - truncated_accuracy: 0.7750 - accuracy: 0.5147 - mae: 0.1097 - val_loss: 0.2257 - val_truncated_accuracy: 0.7590 - val_accuracy: 0.4795 - val_mae: 0.1100
#
# Epoch 00008: val_truncated_accuracy did not improve from 0.75909
# Epoch 9/150
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 2.7236027934238183e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2106 - truncated_accuracy: 0.7755 - accuracy: 0.5061 - mae: 0.1096 - val_loss: 0.2251 - val_truncated_accuracy: 0.7578 - val_accuracy: 0.5210 - val_mae: 0.1100
#
# Epoch 00009: val_truncated_accuracy did not improve from 0.75909
# Epoch 10/150
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 2.6546586816868657e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2104 - truncated_accuracy: 0.7755 - accuracy: 0.5184 - mae: 0.1096 - val_loss: 0.2252 - val_truncated_accuracy: 0.7584 - val_accuracy: 0.5179 - val_mae: 0.1100
#
# Epoch 00010: val_truncated_accuracy did not improve from 0.75909
# Epoch 11/150
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 2.5884723344193908e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2099 - truncated_accuracy: 0.7760 - accuracy: 0.5078 - mae: 0.1096 - val_loss: 0.2255 - val_truncated_accuracy: 0.7583 - val_accuracy: 0.4995 - val_mae: 0.1100
#
# Epoch 00011: val_truncated_accuracy did not improve from 0.75909
# Epoch 12/150
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 2.524933441042615e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2091 - truncated_accuracy: 0.7761 - accuracy: 0.5052 - mae: 0.1095 - val_loss: 0.2251 - val_truncated_accuracy: 0.7585 - val_accuracy: 0.4905 - val_mae: 0.1098
#
# Epoch 00012: val_truncated_accuracy did not improve from 0.75909
# Epoch 13/150
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 2.4639361034009105e-05.
# 10029/10029 [==============================] - 333s 33ms/step - loss: 0.2086 - truncated_accuracy: 0.7771 - accuracy: 0.5108 - mae: 0.1095 - val_loss: 0.2256 - val_truncated_accuracy: 0.7580 - val_accuracy: 0.5782 - val_mae: 0.1099
#
# Epoch 00013: val_truncated_accuracy did not improve from 0.75909
# Epoch 14/150
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 2.405378659264874e-05.
# 10029/10029 [==============================] - 333s 33ms/step - loss: 0.2084 - truncated_accuracy: 0.7769 - accuracy: 0.5176 - mae: 0.1095 - val_loss: 0.2246 - val_truncated_accuracy: 0.7589 - val_accuracy: 0.5273 - val_mae: 0.1099
#
# Epoch 00014: val_truncated_accuracy did not improve from 0.75909
# Epoch 15/150
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 2.349163512894279e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2080 - truncated_accuracy: 0.7771 - accuracy: 0.5208 - mae: 0.1094 - val_loss: 0.2257 - val_truncated_accuracy: 0.7586 - val_accuracy: 0.5140 - val_mae: 0.1097
#
# Epoch 00015: val_truncated_accuracy did not improve from 0.75909
# Epoch 16/150
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 2.295196972378508e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2076 - truncated_accuracy: 0.7773 - accuracy: 0.5233 - mae: 0.1094 - val_loss: 0.2246 - val_truncated_accuracy: 0.7587 - val_accuracy: 0.5356 - val_mae: 0.1099
#
# Epoch 00016: val_truncated_accuracy did not improve from 0.75909
# Epoch 17/150
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 2.2433890934833674e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2071 - truncated_accuracy: 0.7778 - accuracy: 0.5232 - mae: 0.1094 - val_loss: 0.2247 - val_truncated_accuracy: 0.7591 - val_accuracy: 0.5364 - val_mae: 0.1097
#
# Epoch 00017: val_truncated_accuracy improved from 0.75909 to 0.75912, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.759116.hdf5
# Epoch 18/150
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 2.1936535297440327e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2069 - truncated_accuracy: 0.7781 - accuracy: 0.5221 - mae: 0.1093 - val_loss: 0.2247 - val_truncated_accuracy: 0.7589 - val_accuracy: 0.5041 - val_mae: 0.1098
#
# Epoch 00018: val_truncated_accuracy did not improve from 0.75912
# Epoch 19/150
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 2.1459073885542716e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2068 - truncated_accuracy: 0.7783 - accuracy: 0.5112 - mae: 0.1093 - val_loss: 0.2240 - val_truncated_accuracy: 0.7593 - val_accuracy: 0.5250 - val_mae: 0.1099
#
# Epoch 00019: val_truncated_accuracy improved from 0.75912 to 0.75934, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.759338.hdf5
# Epoch 20/150
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 2.1000710930121005e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2064 - truncated_accuracy: 0.7786 - accuracy: 0.5135 - mae: 0.1093 - val_loss: 0.2243 - val_truncated_accuracy: 0.7587 - val_accuracy: 0.5305 - val_mae: 0.1098
#
# Epoch 00020: val_truncated_accuracy did not improve from 0.75934
# Epoch 21/150
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 2.0560682492916165e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2061 - truncated_accuracy: 0.7783 - accuracy: 0.5201 - mae: 0.1093 - val_loss: 0.2254 - val_truncated_accuracy: 0.7582 - val_accuracy: 0.5160 - val_mae: 0.1096
#
# Epoch 00021: val_truncated_accuracy did not improve from 0.75934
# Epoch 22/150
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 2.0138255193199518e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2056 - truncated_accuracy: 0.7791 - accuracy: 0.5244 - mae: 0.1092 - val_loss: 0.2233 - val_truncated_accuracy: 0.7597 - val_accuracy: 0.5119 - val_mae: 0.1098
#
# Epoch 00022: val_truncated_accuracy improved from 0.75934 to 0.75966, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.759659.hdf5
# Epoch 23/150
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 1.973272498547154e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2052 - truncated_accuracy: 0.7793 - accuracy: 0.5171 - mae: 0.1092 - val_loss: 0.2237 - val_truncated_accuracy: 0.7590 - val_accuracy: 0.5644 - val_mae: 0.1100
#
# Epoch 00023: val_truncated_accuracy did not improve from 0.75966
# Epoch 24/150
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 1.9343415986052673e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2052 - truncated_accuracy: 0.7794 - accuracy: 0.5219 - mae: 0.1092 - val_loss: 0.2242 - val_truncated_accuracy: 0.7588 - val_accuracy: 0.5226 - val_mae: 0.1098
#
# Epoch 00024: val_truncated_accuracy did not improve from 0.75966
# Epoch 25/150
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 1.896967934661057e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2048 - truncated_accuracy: 0.7797 - accuracy: 0.5180 - mae: 0.1092 - val_loss: 0.2245 - val_truncated_accuracy: 0.7583 - val_accuracy: 0.5338 - val_mae: 0.1098
#
# Epoch 00025: val_truncated_accuracy did not improve from 0.75966
# Epoch 26/150
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 1.8610892172746145e-05.
# 10029/10029 [==============================] - 333s 33ms/step - loss: 0.2047 - truncated_accuracy: 0.7798 - accuracy: 0.5217 - mae: 0.1092 - val_loss: 0.2253 - val_truncated_accuracy: 0.7584 - val_accuracy: 0.5370 - val_mae: 0.1096
#
# Epoch 00026: val_truncated_accuracy did not improve from 0.75966
# Epoch 27/150
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 1.8266456485836298e-05.
# 10029/10029 [==============================] - 333s 33ms/step - loss: 0.2044 - truncated_accuracy: 0.7800 - accuracy: 0.5180 - mae: 0.1091 - val_loss: 0.2243 - val_truncated_accuracy: 0.7593 - val_accuracy: 0.5282 - val_mae: 0.1098
#
# Epoch 00027: val_truncated_accuracy did not improve from 0.75966
# Epoch 28/150
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 1.7935798226402847e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2041 - truncated_accuracy: 0.7803 - accuracy: 0.5243 - mae: 0.1091 - val_loss: 0.2246 - val_truncated_accuracy: 0.7587 - val_accuracy: 0.5223 - val_mae: 0.1096
#
# Epoch 00028: val_truncated_accuracy did not improve from 0.75966
# Epoch 29/150
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 1.7618366297346733e-05.
# 10029/10029 [==============================] - 334s 33ms/step - loss: 0.2040 - truncated_accuracy: 0.7798 - accuracy: 0.5217 - mae: 0.1091 - val_loss: 0.2243 - val_truncated_accuracy: 0.7585 - val_accuracy: 0.5397 - val_mae: 0.1097
#
# Epoch 00029: val_truncated_accuracy did not improve from 0.75966
# Epoch 30/150
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 1.7313631645452863e-05.
# 10029/10029 [==============================] - 336s 33ms/step - loss: 0.2038 - truncated_accuracy: 0.7802 - accuracy: 0.5251 - mae: 0.1091 - val_loss: 0.2236 - val_truncated_accuracy: 0.7589 - val_accuracy: 0.5143 - val_mae: 0.1099
#
# Epoch 00030: val_truncated_accuracy did not improve from 0.75966
# Epoch 31/150
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 1.7021086379634746e-05.
# 10029/10029 [==============================] - 336s 33ms/step - loss: 0.2036 - truncated_accuracy: 0.7806 - accuracy: 0.5197 - mae: 0.1091 - val_loss: 0.2227 - val_truncated_accuracy: 0.7593 - val_accuracy: 0.5026 - val_mae: 0.1100
#
# Epoch 00031: val_truncated_accuracy did not improve from 0.75966
# Epoch 32/150
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 1.6740242924449357e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2030 - truncated_accuracy: 0.7812 - accuracy: 0.5140 - mae: 0.1090 - val_loss: 0.2242 - val_truncated_accuracy: 0.7597 - val_accuracy: 0.5247 - val_mae: 0.1096
#
# Epoch 00032: val_truncated_accuracy improved from 0.75966 to 0.75968, saving model to /content/drive/MyDrive/bio-data/AN1-saint-base-build-MHA-2-no-phy-pro-CLB-FinalRun-1/best-0.759675.hdf5
# Epoch 33/150
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 1.6470633207471384e-05.
# 10029/10029 [==============================] - 335s 33ms/step - loss: 0.2032 - truncated_accuracy: 0.7808 - accuracy: 0.5176 - mae: 0.1090 - val_loss: 0.2234 - val_truncated_accuracy: 0.7596 - val_accuracy: 0.5293 - val_mae: 0.1098
#
# Epoch 00033: val_truncated_accuracy did not improve from 0.75968
# Epoch 34/150
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 1.6211807879172527e-05.
#  7940/10029 [======================>.......] - ETA: 1:08 - loss: 0.2028 - truncated_accuracy: 0.7820 - accuracy: 0.5167 - mae: 0.1089

# %% [markdown]
# **Inference**

# %%
############## change validation set to other set for validations
############## 

predX = np.load('/content/training-needs/validationX.npy')
print(predX.shape)
predY = np.load('/content/training-needs/validationY.npy')[:,:,:8]
print(predY.shape)
predAttm = np.load('/content/training-needs/validationAttM.npy')
print(predAttm.shape)
predPosIds = np.array(range(700))
predPosIds = np.repeat([predPosIds], int(predX.shape[0]), axis=0)
print(predPosIds.shape)

# %%
# predictions = model.predict([validationX,validationAttm,validationPosIds],verbose = 1)
model.evaluate([predX,predAttm,predPosIds], predY,verbose = 1)
