# %%
save_path = '/content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/'

# %%
# !nvidia-smi
# Out:
# Tue Nov 23 17:24:17 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import shutil
shutil.copyfile('/content/drive/MyDrive/bio-data/ok.zip', './ok.zip')
# !unzip ok.zip
# Out:
# Archive:  ok.zip
#    creating: Test/
#   inflating: Test/5G6UA.fasta
#   inflating: Test/5G6UA.hhm
#   inflating: Test/5G6UA.pssm
#   inflating: Test/5G6UA.spotcon
#   inflating: Test/5G6UA.ss
#   inflating: Test/5H7KA.fasta
#   inflating: Test/5H7KA.hhm
#   inflating: Test/5H7KA.pssm
#   inflating: Test/5H7KA.spotcon
#   inflating: Test/5H7KA.ss
#   inflating: 0norm_data.p
#   inflating: 1norm_data.p
#   inflating: 5norm_data.p
#   inflating: aa_phy7
#   inflating: config.py
#   inflating: GenerateBaseFeature.py
#   inflating: GenerateForWindow10.py
#   inflating: GenerateForWindow20.py
#   inflating: GenerateForWindow50.py
#   inflating: GenerateLengthList.py
#   inflating: list_test
#   inflating: SAINT_ensemble.py
#   inflating: SAINT_single_base_model.py

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
########### Select Tensorflow and Keras Version
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
########## imports
# tensorflow and keras functions
import tensorflow as tensorflow
import keras
from keras import backend as K
from keras.models import Sequential
from keras.models import Model
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.embeddings import Embedding
from keras.layers.recurrent import LSTM, GRU
from keras.layers import Input,SpatialDropout1D, Embedding, LSTM, Dense, merge, Convolution2D, Lambda, GRU, TimeDistributed, Reshape, Permute, Convolution1D, Masking, Bidirectional
from keras.optimizers import Adam
from keras.layers import concatenate
from keras.regularizers import l2
from keras.callbacks import ModelCheckpoint
from keras import optimizers, callbacks
from keras.layers import Layer
from keras.initializers import Ones, Zeros
from keras.layers import Layer
from keras.engine.topology import Layer
from keras.layers import add
from keras.layers import RepeatVector, Multiply, Flatten, Dot, Softmax, Lambda
from keras import backend
from keras.layers import RepeatVector
from keras.layers import Embedding, Add, concatenate
from keras.layers import BatchNormalization, Dropout

# python built-in
from time import time
import numpy as np
import gc
import random
import math
from numpy import random as nprand

# custom 
import config
from config import *
from GenerateBaseFeature import generateBaseDataset
from GenerateLengthList import generateLengthlistAndAttentionMask

print(tensorflow.__version__)
print(keras.__version__)
# Out:
# 1.15.2
# 2.3.1
# Using TensorFlow backend.

# %%
def truncated_accuracy(y_true, y_predict):
    mask = K.sum(y_true, axis=2)
    y_pred_labels = K.cast(K.argmax(y_predict, axis=2), 'float32')
    y_true_labels = K.cast(K.argmax(y_true, axis=2), 'float32')
    is_same = K.cast(K.equal(
        y_true_labels, y_pred_labels), 'float32')
    num_same = K.sum(is_same * mask, axis=1)
    lengths = K.sum(mask, axis=1)
    # return K.cast(K.sum(num_same, axis=0) / K.sum(lengths, axis=0), 'float32')
    return Lambda(lambda x: x[0]/x[1])([K.sum(num_same, axis=0), K.sum(lengths, axis=0)])

class LayerNormalization(Layer):
    def __init__(self, eps: float = 1e-5, **kwargs) -> None:
        self.eps = eps
        super().__init__(**kwargs)

    def build(self, input_shape):
        self.gamma = self.add_weight(name='gamma', shape=input_shape[-1:], initializer=Ones(), trainable=True)
        self.beta = self.add_weight(name='beta', shape=input_shape[-1:], initializer=Zeros(), trainable=True)
        super().build(input_shape)

    def call(self, x, **kwargs):
        u = K.mean(x, axis=-1, keepdims=True)
        s = K.mean(K.square(x - u), axis=-1, keepdims=True)
        z = (x - u) / K.sqrt(s + self.eps)
        return self.gamma * z + self.beta

    def compute_output_shape(self, input_shape):
        return input_shape

    def get_config(self):
        config = {
            'eps': self.eps,
        }
        base_config = super().get_config()
        return dict(list(base_config.items()) + list(config.items()))

class MyLayer(Layer):
    def __init__(self, **kwargs):
        super(MyLayer, self).__init__(**kwargs)

    def build(self, input_shape):

        self._x = K.variable(0.2)
        self._x._trainable = True
        self.trainable_weights = [self._x]

        super(MyLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, x):
        A, B = x
        result = add([self._x*A ,(1-self._x)*B])
        return result

    def compute_output_shape(self, input_shape):
        return input_shape[0]

def attention(activations):
#https://arxiv.org/pdf/1703.03130.pdf
    d_a = 10
    r = 1
    units = activations.shape[2]
    #print(activations.shape)
    attention = TimeDistributed(Dense(d_a, activation='tanh', use_bias=False))(activations)
    attention = Dropout(.5)(attention)
    #print(attention.shape)
    attention = TimeDistributed(Dense(r, activation='softmax', use_bias=False))(activations) 
    #print(attention.shape)
    attention = Flatten()(attention)
    #attention = Activation('softmax')(attention)
    attention = RepeatVector(units)(attention)
    #print(attention.shape)
    attention = Permute([2, 1])(attention)
    #print(attention.shape)

    # apply the attention
    sent_representation = Multiply()([activations, attention])
    #sent_representation = Lambda(lambda xin: K.dot(xin[0], xin[1]))([attention, activations])
    #print(sent_representation.shape)
    #sent_representation = Lambda(lambda xin: K.sum(xin, axis=1))(sent_representation)
    #print(sent_representation.shape)
    return sent_representation

def shape_list(x):
    #   https://github.com/Separius/BERT-keras/blob/master/transformer/funcs.py
    if backend.backend() != 'theano':
        tmp = backend.int_shape(x)
    else:
        tmp = x.shape
    tmp = list(tmp)
    tmp[0] = -1
    return tmp

def attention_scaled_dot(activations, attention_mask, head = 1): #, length):
#https://arxiv.org/pdf/1706.03762.pdf
    units = int(activations.shape[2])
    words = int(activations.shape[1])
    print('Activations.shape: ',activations.shape)
    _drop_rate_ = .1
    hidden_dimension = int(units/head)
    Q = TimeDistributed(Dense(hidden_dimension, activation=None, use_bias=False))(activations)
    Q = Dropout(_drop_rate_)(Q)
    K = TimeDistributed(Dense(hidden_dimension, activation=None, use_bias=False))(activations)
    K = Dropout(_drop_rate_)(K)
    V = TimeDistributed(Dense(hidden_dimension, activation=None, use_bias=False))(activations)
    V = Dropout(_drop_rate_)(V)
    print('Q.shape: ',Q.shape)
    QK_T = Dot(axes=-1, normalize=False)([Q,K]) # list of two tensors
    print('QK_T.shape: ', QK_T.shape)
    """normalize: Whether to L2-normalize samples along the dot product axis before taking the dot product. If set to True, then the output of the dot product is the cosine proximity between the two samples."""
    QK_T = Lambda( lambda inp: inp[0]/ backend.sqrt(backend.cast(shape_list(inp[1])[-1], backend.floatx())))([QK_T, V])
    print('QK_T.shape: ', QK_T.shape)
    
#     cropping = np.zeros(QK_T.shape[1])
#     cropping[length:] = (-10**6) * np.ones(int(QK_T.shape[1])-length)
#     QK_T = QK_T + cropping
    print('att mask origin shape: ',attention_mask.shape)
    attention_mask__ = RepeatVector(int(QK_T.shape[1]))(attention_mask)
    print('att mask shape: ',attention_mask__.shape)
    QK_T = Add()([QK_T, attention_mask__])
    print('Add QK and mask: ',attention_mask__.shape)
    QK_T = Softmax(axis=-1)(QK_T)
    QK_T = Dropout(_drop_rate_)(QK_T)
    #print(V.shape)
    V = Permute([2, 1])(V)
    print('V premute shape: ', V.shape)
    V_prime = Dot(axes=-1, normalize=False)([QK_T,V]) # list of two tensors
    print('V_prime shape: ', V_prime.shape)
    return V_prime

def _get_pos_encoding_matrix(protein_len: int, d_emb: int) -> np.array:
    pos_enc = np.array(
        [[pos / np.power(10000, 2 * (j // 2) / d_emb) for j in range(d_emb)] if pos != 0 else np.zeros(d_emb) for pos in
         range(protein_len)], dtype=np.float32)
    pos_enc[1:, 0::2] = np.sin(pos_enc[1:, 0::2])  # dim 2i
    pos_enc[1:, 1::2] = np.cos(pos_enc[1:, 1::2])  # dim 2i+1
    return pos_enc

def embeddings(inputs):
    gene_ids, pos_ids = inputs
    gene_vocab_len = 22
    protein_len = 700
    output_dim = 50
    gene_embedding = Embedding(gene_vocab_len, output_dim, input_length=protein_len,
                                              name='GeneEmbedding')(gene_ids)

    pos_embedding = Embedding(protein_len, output_dim, trainable=False, input_length=protein_len,
                                              name='PositionEmbedding',
                                              weights=[_get_pos_encoding_matrix(protein_len, output_dim)])(pos_ids)

    summation = Add(name='AddEmbeddings')([Dropout(.1, name='EmbeddingDropOut1')(gene_embedding), 
                                           Dropout(.1, name='EmbeddingDropOut2')(pos_embedding)])
    
#     summation = concatenate([Dropout(.1, name='EmbeddingDropOut1')(gene_embedding), 
#                              Dropout(.1, name='EmbeddingDropOut2')(pos_embedding)])
    
    summation = LayerNormalization(1e-5)(summation)
    return summation

def gene_embeddings(gene_ids, output_dim=50):
    gene_vocab_len = 22
    protein_len = 700
    
    gene_emb = Dropout(.1)(Embedding(gene_vocab_len, output_dim, input_length=protein_len,
                               name='GeneEmbedding')(gene_ids))

    gene_emb = LayerNormalization(1e-5)(gene_emb)
    return gene_emb


def position_embedding(pos_ids, output_dim=50):
    #gene_vocab_len = 22
    protein_len = 700
    output_dim = int(output_dim)

    pos_emb = Dropout(.1)(Embedding(protein_len, output_dim, trainable=False, input_length=protein_len,
                        #name='PositionEmbedding',
                        weights=[_get_pos_encoding_matrix(protein_len, output_dim)])(pos_ids))
    
    pos_emb = LayerNormalization(1e-5)(pos_emb)
    return pos_emb


def attention_module(x, attention_mask, pos_ids=None, drop_rate=.1, ccnt=None, head = 1):
    
    original_dim = int(x.shape[-1])
    
    if ccnt is not None:
        print('aatt--------x1-> '+str(x.shape))
        print('original dim--------x1-> '+str(original_dim))
    if pos_ids is not None:
        pos_embedding = position_embedding(pos_ids=pos_ids, output_dim=original_dim)
        #x = concatenate([x, pos_embedding])
        x = Add()([x, pos_embedding])

    if ccnt is not None:
        print('aatt--------x2-> '+str(x.shape))

    
    att_layer_head1 = attention_scaled_dot(x, attention_mask, head) ## our code
    att_layer_head2 = attention_scaled_dot(x, attention_mask, head) ## our code

    att_layer = keras.layers.Concatenate(axis = -1)([att_layer_head1,att_layer_head2]) ## our code
    if ccnt is not None:
        print('aatt--------att_layer1-> '+str(att_layer.shape))
    att_layer = Dropout(drop_rate)(att_layer)

    att_layer = TimeDistributed(Dense(original_dim, activation=None, use_bias=False))(att_layer) ## our code

    if ccnt is not None:
        print('aatt--------att_layer2-> '+str(att_layer.shape))
    x = MyLayer()([att_layer, x])

    if ccnt is not None:
        print('aatt--------my-> '+str(x.shape))
    x = Dropout(drop_rate)(x)
    x = BatchNormalization()(x)
#     if False:
#         # reduce dim
#         x = Convolution1D(original_dim, 1, activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
#         x = Dropout(drop_rate*2)(x)
#         x = BatchNormalization()(x)
    # ccnt +=1
    return x

def inceptionBlock(x):
    _drop_rate_ = .1
    x = BatchNormalization()(x)
    print('inceptionblock before CONV '+ str(x.shape))
    conv1_1 = Convolution1D(100, 1, activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    print('inceptionblock after CONV '+ str(conv1_1.shape))
    conv1_1 = Dropout(_drop_rate_)(conv1_1) #https://www.quora.com/Can-l-combine-dropout-and-l2-regularization
    conv1_1 = BatchNormalization()(conv1_1)
    
    conv2_1 = Convolution1D(100, 1, activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    conv2_1 = Dropout(_drop_rate_)(conv2_1)
    conv2_1 = BatchNormalization()(conv2_1)
    conv2_2 = Convolution1D(100, 3, activation='relu', padding='same', kernel_regularizer=l2(0.001))(conv2_1)
    conv2_2 = Dropout(_drop_rate_)(conv2_2)
    conv2_2 = BatchNormalization()(conv2_2)
    
    conv3_1 = Convolution1D(100, 1, activation='relu', padding='same', kernel_regularizer=l2(0.001))(x)
    conv3_1 = Dropout(_drop_rate_)(conv3_1)
    conv3_1 = BatchNormalization()(conv3_1)
    conv3_2 = Convolution1D(100, 3, activation='relu', padding='same', kernel_regularizer=l2(0.001))(conv3_1)
    conv3_2 = Dropout(_drop_rate_)(conv3_2)
    conv3_2 = BatchNormalization()(conv3_2)
    conv3_3 = Convolution1D(100, 3, activation='relu', padding='same', kernel_regularizer=l2(0.001))(conv3_2)
    conv3_3 = Dropout(_drop_rate_)(conv3_3)
    conv3_3 = BatchNormalization()(conv3_3)
    conv3_4 = Convolution1D(100, 3, activation='relu', padding='same', kernel_regularizer=l2(0.001))(conv3_3)
    conv3_4 = Dropout(_drop_rate_)(conv3_4)
    conv3_4 = BatchNormalization()(conv3_4)
    
    concat = concatenate([conv1_1, conv2_2, conv3_4])
    concat = BatchNormalization()(concat)
    
    return concat

def deep3iBLock_with_attention(x, attention_mask, pos_ids=None):
    print('x-> '+str(x.shape))
    block1_1 = inceptionBlock(x)
    print('block1_1-> '+str(block1_1.shape))
    block1_1 = attention_module(block1_1, attention_mask, pos_ids,ccnt=1, head = 2)
    print('block1_1-> '+str(block1_1.shape))

    block2_1 = inceptionBlock(x)
    print('block2_1-> '+str(block2_1.shape))
    block2_2 = inceptionBlock(block2_1)
    print('block2_1-> '+str(block2_1.shape))
    block2_2 = attention_module(block2_2, attention_mask, pos_ids, head = 2)
    print('block2_2-> '+str(block2_2.shape))


    block3_1 = inceptionBlock(x)
    block3_2 = inceptionBlock(block3_1)
    block3_3 = inceptionBlock(block3_2)
    block3_4 = inceptionBlock(block3_3)
    print('block3_4-> '+str(block3_4.shape))
    block3_4 = attention_module(block3_4, attention_mask, pos_ids, head = 2)
    print('block3_4-> '+str(block3_4.shape))

    concat = concatenate([block1_1, block2_2, block3_4])
    concat = BatchNormalization()(concat)
    
    return concat

def get_model(num_feature):
#   pssm_input = Input(shape=(700,21,), name='pssm_input')
#   seq_input = Input(shape=(700,22,), name='seq_input')
  _drop_rate_ = .4
  main_input = Input(shape=(700,num_feature,), name='main_input')
  attention_mask = Input(shape=(700,), name='attention_mask')
  pos_ids = Input(shape=(700,), name='position_input', dtype='int32')
  
  #pos_emb = position_embedding(pos_ids, output_dim=50)
#   main_input = concatenate([seq_input, pssm_input])
  
  block1 = deep3iBLock_with_attention(main_input, attention_mask, pos_ids)
#   att_layer_4 = attention_scaled_dot(block1)
#   block1 = MyLayer()([att_layer_4 ,block1])
#   block1 = BatchNormalization()(block1)
  
  block2 = deep3iBLock_with_attention(block1, attention_mask, pos_ids)
  block2 = attention_module(block2, attention_mask, pos_ids, head = 2)
  
  conv11 = Convolution1D(100, 11, activation='relu', padding='same', kernel_regularizer=l2(0.001))(block2)
#   conv11 = BatchNormalization()(conv11)
  conv11 = attention_module(conv11, attention_mask, pos_ids, head = 2)

  dense1 = TimeDistributed(Dense(units=256,activation='relu'))(conv11)
  dense1 = Dropout(_drop_rate_)(dense1)
  dense1 = attention_module(dense1, attention_mask, pos_ids, head = 2)
  
  print('before final: -------------------' + str(dense1.shape))
  main_output = TimeDistributed(Dense(units=8,activation='softmax', name='main_output'))(dense1)
  print('after final: -------------------' + str(main_output.shape))
#   main_output = TimeDistributed(Dense(units=8,activation='softmax', name='main_output'))(block1)
  
  model = Model([main_input, attention_mask, pos_ids],main_output)
  return model

class StepDecay():
  def __init__(self, initAlpha=0.0005, factor=0.9, dropEvery=60, min_lr=0.00001):
    self.initAlpha = initAlpha
    self.factor = factor
    self.dropEvery = dropEvery
    self.min_lr = min_lr

  def __call__(self, epoch):
    exp = np.floor((epoch + 1) / self.dropEvery)
    alpha = self.initAlpha * (self.factor ** exp)
    if float(alpha) > self.min_lr:
        print('lr:', alpha)
        return float(alpha)
    else:
        print('lr:', self.min_lr)
        return self.min_lr
    
def get_lr_metric(optimizer):
    def lr(y_true, y_pred):
        return optimizer.lr
    return lr

# %%
model = get_model(num_feature=57)
# model.summary()
# Out:
# x-> (?, 700, 57)
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# inceptionblock before CONV (?, 700, 57)
# inceptionblock after CONV (?, 700, 100)
# block1_1-> (?, 700, 300)
# aatt--------x1-> (?, 700, 300)
# original dim--------x1-> 300
# aatt--------x2-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# aatt--------att_layer1-> (?, 700, 300)
# aatt--------att_layer2-> (?, 700, 300)
# tracking <tf.Variable 'my_layer_1/Variable:0' shape=() dtype=float32> _x
# aatt--------my-> (?, 700, 300)
# block1_1-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 57)
# inceptionblock after CONV (?, 700, 100)
# block2_1-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# block2_1-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# tracking <tf.Variable 'my_layer_2/Variable:0' shape=() dtype=float32> _x
# block2_2-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 57)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# block3_4-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# tracking <tf.Variable 'my_layer_3/Variable:0' shape=() dtype=float32> _x
# block3_4-> (?, 700, 300)
# x-> (?, 700, 900)
# inceptionblock before CONV (?, 700, 900)
# inceptionblock after CONV (?, 700, 100)
# block1_1-> (?, 700, 300)
# aatt--------x1-> (?, 700, 300)
# original dim--------x1-> 300
# aatt--------x2-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# aatt--------att_layer1-> (?, 700, 300)
# aatt--------att_layer2-> (?, 700, 300)
# tracking <tf.Variable 'my_layer_4/Variable:0' shape=() dtype=float32> _x
# aatt--------my-> (?, 700, 300)
# block1_1-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 900)
# inceptionblock after CONV (?, 700, 100)
# block2_1-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# block2_1-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# tracking <tf.Variable 'my_layer_5/Variable:0' shape=() dtype=float32> _x
# block2_2-> (?, 700, 300)
# inceptionblock before CONV (?, 700, 900)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# inceptionblock before CONV (?, 700, 300)
# inceptionblock after CONV (?, 700, 100)
# block3_4-> (?, 700, 300)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# Activations.shape:  (?, 700, 300)
# Q.shape:  (?, 700, 150)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 150, 700)
# V_prime shape:  (?, 700, 150)
# tracking <tf.Variable 'my_layer_6/Variable:0' shape=() dtype=float32> _x
# block3_4-> (?, 700, 300)
# Activations.shape:  (?, 700, 900)
# Q.shape:  (?, 700, 450)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 450, 700)
# V_prime shape:  (?, 700, 450)
# Activations.shape:  (?, 700, 900)
# Q.shape:  (?, 700, 450)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 450, 700)
# V_prime shape:  (?, 700, 450)
# tracking <tf.Variable 'my_layer_7/Variable:0' shape=() dtype=float32> _x
# Activations.shape:  (?, 700, 100)
# Q.shape:  (?, 700, 50)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 50, 700)
# V_prime shape:  (?, 700, 50)
# Activations.shape:  (?, 700, 100)
# Q.shape:  (?, 700, 50)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 50, 700)
# V_prime shape:  (?, 700, 50)
# tracking <tf.Variable 'my_layer_8/Variable:0' shape=() dtype=float32> _x
# Activations.shape:  (?, 700, 256)
# Q.shape:  (?, 700, 128)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 128, 700)
# V_prime shape:  (?, 700, 128)
# Activations.shape:  (?, 700, 256)
# Q.shape:  (?, 700, 128)
# QK_T.shape:  (?, 700, 700)
# QK_T.shape:  (?, 700, 700)
# att mask origin shape:  (?, 700)
# att mask shape:  (?, 700, 700)
# Add QK and mask:  (?, 700, 700)
# V premute shape:  (?, 128, 700)
# V_prime shape:  (?, 700, 128)
# tracking <tf.Variable 'my_layer_9/Variable:0' shape=() dtype=float32> _x
# before final: -------------------(?, 700, 256)
# after final: -------------------(?, 700, 8)

# %%
# !pip install 'h5py==2.10.0' --force-reinstall

# %%
# model.load_weights('/content/drive/MyDrive/bio-data/amlan-21-Nov-2021/best-0.749.hdf5')
# model.load_weights('./SAINT_win0_weights.h5')

# %% [markdown]
# # Our Code

# %% [markdown]
# ## Callbacks

# %%
def set_es(loss_to_monitor = 'val_truncated_accuracy', patience = 20, verbosity = True):
    global es_callback
    es_callback = tensorflow.keras.callbacks.EarlyStopping(monitor=loss_to_monitor, patience=patience, verbose=verbosity)

set_es()

# %%
# Learning rate
import matplotlib.pyplot as plt

start_lr = 1e-7
min_lr = 1e-5
max_lr = 1e-3
rampup_epochs = 10
sustain_epochs = 0
exp_decay = .96
d_model = 512

current_epoch = 0

def lrfn(epoch):
    global current_epoch

    if current_epoch < rampup_epochs:
        lr = (max_lr - start_lr)/rampup_epochs * current_epoch + start_lr
        current_epoch += 1
        return lr
    elif current_epoch < rampup_epochs + sustain_epochs:
        current_epoch += 1
        return max_lr
    else:
        lr = (max_lr - min_lr) * exp_decay**(current_epoch-rampup_epochs-sustain_epochs) + min_lr
        current_epoch += 1
        return lr
    # steps_per_epoch = 500
    # step = epoch * steps_per_epoch
    # warmup_steps = rampup_epochs * steps_per_epoch
    # arg1 = step ** -0.5
    # arg2 = step * (warmup_steps ** -1.5)

    # return (d_model**-0.5) * min(arg1, arg2)

lr_callback = tensorflow.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

rang = np.arange(150)
y = [lrfn(x) for x in rang]
print(y)
plt.plot(rang, y)
current_epoch = 0
# Out:
# [1e-07, 0.00010009, 0.00020008, 0.00030007, 0.00040006, 0.0005000499999999999, 0.0006000399999999999, 0.0007000299999999999, 0.0008000199999999999, 0.0009000099999999999, 0.001, 0.0009604, 0.0009223839999999999, 0.0008858886399999999, 0.0008508530943999999, 0.0008172189706239999, 0.0007849302117990399, 0.0007539330033270782, 0.000724175683193995, 0.0006956086558662352, 0.0006681843096315858, 0.0006418569372463224, 0.0006165826597564695, 0.0005923193533662106, 0.0005690265792315622, 0.0005466655160622998, 0.0005251988954198077, 0.0005045909396030154, 0.0004848073020188947, 0.0004658150099381389, 0.00044758240954061336, 0.0004300791131589888, 0.0004132759486326292, 0.00039714491068732405, 0.0003816591142598311, 0.0003667927496894378, 0.0003525210397018603, 0.0003388201981137859, 0.00032566739018923446, 0.000313040694581665, 0.00030091906679839843, 0.0002892823041264625, 0.000278111011961404, 0.0002673865714829478, 0.0002570911086236299, 0.00024720746427868466, 0.00023771916570753724, 0.00022861039907923574, 0.00021986598311606634, 0.00021147134379142366, 0.00020341249003976672, 0.00019567599043817605, 0.00018824895082064899, 0.00018111899278782303, 0.0001742742330763101, 0.00016770326375325768, 0.00016139513320312737, 0.0001553393278750023, 0.00014952575476000218, 0.0001439447245696021, 0.000138586935586818, 0.00013344345816334528, 0.00012850571983681147, 0.000123765491043339, 0.00011921487140160543, 0.0001148462765455412, 0.00011065242548371957, 0.00010662632846437077, 0.00010276127532579594, 9.905082431276409e-05, 9.548879134025353e-05, 9.206923968664338e-05, 8.878647009917764e-05, 8.563501129521054e-05, 8.260961084340211e-05, 7.970522640966602e-05, 7.691701735327939e-05, 7.424033665914821e-05, 7.167072319278228e-05, 6.920389426507099e-05, 6.683573849446814e-05, 6.456230895468941e-05, 6.237981659650184e-05, 6.028462393264176e-05, 5.8273238975336084e-05, 5.6342309416322645e-05, 5.4488617039669736e-05, 5.2709072358082945e-05, 5.1000709463759625e-05, 4.9360681085209236e-05, 4.7786253841800864e-05, 4.627480368812883e-05, 4.4823811540603674e-05, 4.3430859078979526e-05, 4.2093624715820346e-05, 4.080987972718753e-05, 3.957748453810003e-05, 3.839438515657603e-05, 3.7258609750312986e-05, 3.616826536030047e-05, 3.5121534745888444e-05, 3.4116673356052906e-05, 3.3152006421810787e-05, 3.222592616493836e-05, 3.133688911834082e-05, 3.048341355360719e-05, 2.96640770114629e-05, 2.8877513931004383e-05, 2.8122413373764207e-05, 2.7397516838813638e-05, 2.6701616165261094e-05, 2.6033551518650647e-05, 2.5392209457904624e-05, 2.4776521079588435e-05, 2.4185460236404898e-05, 2.36180418269487e-05, 2.3073320153870754e-05, 2.2550387347715923e-05, 2.2048371853807284e-05, 2.1566436979654992e-05, 2.1103779500468796e-05, 2.0659628320450044e-05, 2.023324318763204e-05, 1.9823913460126756e-05, 1.9430956921721687e-05, 1.905371864485282e-05, 1.8691569899058705e-05, 1.8343907103096356e-05, 1.8010150818972503e-05, 1.7689744786213605e-05, 1.738215499476506e-05, 1.7086868794974455e-05, 1.6803394043175478e-05, 1.6531258281448456e-05, 1.627000795019052e-05, 1.6019207632182898e-05, 1.5778439326895582e-05, 1.554730175381976e-05, 1.532540968366697e-05, 1.511239329632029e-05, 1.4907897564467478e-05, 1.4711581661888778e-05, 1.4523118395413227e-05, 1.4342193659596698e-05, 1.416850591321283e-05, 1.4001765676684318e-05, 1.3841695049616943e-05, 1.3688027247632266e-05, 1.3540506157726976e-05, 1.3398885911417897e-05]

# %%
# Checkpoint
def set_cp(file = 'best.hdf5', monitor = 'val_loss', verbosity = 1, monitor_mode = 'auto', only_weights = True, best_only = True):
    global cp_callback

    cp_callback = keras.callbacks.ModelCheckpoint(filepath = save_path + 'best-{val_truncated_accuracy:.6f}.hdf5',
                                                monitor = monitor,
                                                verbose = verbosity,
                                                mode= monitor_mode, 
                                                save_weights_only = only_weights, 
                                                save_best_only = best_only)

set_cp(monitor = 'val_truncated_accuracy', only_weights=False)

# %% [markdown]
# ## Train

# %%
model.compile(optimizer=Adam(),
              loss='categorical_crossentropy', #https://github.com/LucaAngioloni/ProteinSecondaryStructure-CNN/blob/master/dataset.py
              sample_weight_mode='temporal',
              metrics=[truncated_accuracy, 'accuracy','mae'])

# %%
# ss8_win0 = model.predict([features0, attention_mask, pos_ids])
# print(ss8_win0.shape)

# %%
# ss8_win0_ = np.argmax(ss8_win0, axis=-1)
# print(ss8_win0_.shape)

# %%
trainX = np.load('/content/drive/MyDrive/bio-data/trainX.npy')
print(trainX.shape)
# Out:
# (10029, 700, 57)

# %%
trainY = np.load('/content/drive/MyDrive/bio-data/trainY.npy')[:,:,:8]
print(trainY.shape)
# Out:
# (10029, 700, 8)

# %%
trainAttm = np.load('/content/drive/MyDrive/bio-data/trainAttM.npy')
print(trainAttm.shape)
# Out:
# (10029, 700)

# %%
trainPosIds = np.array(range(700))
trainPosIds = np.repeat([trainPosIds], int(trainX.shape[0]), axis=0)
print(trainPosIds.shape)
# Out:
# (10029, 700)

# %%
validationX = np.load('/content/drive/MyDrive/bio-data/validationX.npy')
print(validationX.shape)
validationY = np.load('/content/drive/MyDrive/bio-data/validationY.npy')[:,:,:8]
print(validationY.shape)
validationAttm = np.load('/content/drive/MyDrive/bio-data/validationAttM.npy')
print(validationAttm.shape)
validationPosIds = np.array(range(700))
validationPosIds = np.repeat([validationPosIds], int(validationX.shape[0]), axis=0)
print(validationPosIds.shape)
# Out:
# (983, 700, 57)
# (983, 700, 8)
# (983, 700)
# (983, 700)

# %%
trainX = np.float32(trainX)
trainAttm = np.float32(trainAttm)
trainPosIds = np.float32(trainPosIds)
trainY = np.int32(trainY)
validationX = np.float32(validationX)
validationAttm = np.float32(validationAttm)
validationPosIds = np.float32(validationPosIds)
validationY = np.int32(validationY)

# %%
print(type(trainX[0,0,0]))
print(type(trainY[0,0,0]))
print(type(trainAttm[0,0]))
print(type(trainPosIds[0,0]))
print(type(validationX[0,0,0]))
print(type(validationY[0,0,0]))
print(type(validationAttm[0,0]))
print(type(validationPosIds[0,0]))
# Out:
# <class 'numpy.float32'>
# <class 'numpy.int32'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>
# <class 'numpy.int32'>
# <class 'numpy.float32'>
# <class 'numpy.float32'>

# %%
sums_train =  np.sum(trainX,axis=-1)
len_train=np.zeros((trainX.shape[0]))
for i in range(sums_train.shape[0]):
    for j in range(700):
        if sums_train[i,j]==0:
            len_train[i] = j
            break
        if j==699:
            len_train[i] = 700
print(len(len_train))

sums_validation =  np.sum(validationX,axis=-1)
len_validation=np.zeros((validationX.shape[0]))
for i in range(sums_validation.shape[0]):
    for j in range(700):
        if sums_validation[i,j]==0:
            len_validation[i] = j
            break
        if j==699:
            len_validation[i] = 700
print(len(len_validation))
# Out:
# 10029
# 983

# %%
len_shift_train = 700 - len_train
len_shift_validation = 700 - len_validation

# %%
print(keras.backend.floatx())
# Out:
# float32

# %% [markdown]
# **Custom data Generator and Training Loops ** 😑

# %%
class DataGenerator(tensorflow.keras.utils.Sequence):
    def __init__(self, X,X1,X2, Y, shift = None, batch_size=32, shuffle=False):
        self.X = X
        self.X1 = X1
        self.X2 = X2
        self.Y = Y
        self.N = X.shape[0]
        self.batch_size = batch_size
        self.indices = np.arange(self.N)
        self.shuffle = shuffle
        self.shift = shift
        
        # start shuffle from 1st epoch
        self.on_epoch_end()

    def __len__(self):
        return math.ceil((1.0* self.N) / self.batch_size)

    def __getitem__(self, index):
        batch = self.indices[index * self.batch_size:min((index + 1) * self.batch_size,self.N)]
        x, y = self.__get_data(batch)        
        return x, y

    def on_epoch_end(self):
        if self.shuffle == True:
            self.indices = np.arange(self.N)
            np.random.shuffle(self.indices)

    def __get_data(self, batch):
        #### random shift
        rd_for_shift = nprand.rand(len(batch))
        to_shift = np.round(rd_for_shift * self.shift[batch]).astype(int)

        x = np.asarray([np.roll(row, to_shift[i], axis = 0)  for i,row in  enumerate(self.X[batch])])
        x1 = np.asarray([np.roll(row, to_shift[i], axis = 0)  for i,row in  enumerate(self.X1[batch])])
        x2 = np.asarray([np.roll(row, to_shift[i], axis = 0)  for i,row in  enumerate(self.X2[batch])])
        
        y = np.asarray([np.roll(row, to_shift[i], axis = 0)  for i,row in  enumerate(self.Y[batch])])
        #### random shift
        return [x,x1,x2], y
        # return [self.X[batch],self.X1[batch],self.X2[batch]],self.Y[batch]

# %%
cnt_haha = 0
for batch in DataGenerator(trainX,trainAttm,trainPosIds,trainY,len_shift_train,batch_size=1,shuffle=True):
    # print(cnt_haha)
    cnt_haha+=1

    xx,yy=batch
    # print(xx[2].shape)
    yy = np.sum(yy,axis = -1)
    xx1 = np.sum(xx[0], axis = -1)
    xx2 = xx[1]
    xx3 = xx[2]

    print(yy.shape)
    print(xx1.shape)
    print(xx2.shape)

    st_yy = 10000
    et_yy = -1
    for i in range(700):
      if yy[0,i] == 1:
        st_yy = min(i,st_yy)
        et_yy = max(i,et_yy)

    st_xx1 = 10000
    et_xx1 = -1
    for i in range(700):
      if xx1[0,i] != 0:
        st_xx1 = min(i,st_xx1)
        et_xx1 = max(i,et_xx1)

    st_xx2 = 10000
    et_xx2 = -1
    for i in range(700):
      if xx2[0,i] == 0:
        st_xx2 = min(i,st_xx2)
        et_xx2 = max(i,et_xx2)

    print(st_yy,et_yy)
    print(st_xx1,et_xx1)
    print(st_xx2,et_xx2)
    # print(np.where(xx1[0,:]!=0))
    # print(np.where(xx2[0,:]==0))
    # print(np.where(yy[0,:]==1))
    if cnt_haha == 5:
      break
# Out:
# (1, 700)
# (1, 700)
# (1, 700)
# 97 255
# 97 255
# 97 255
# (1, 700)
# (1, 700)
# (1, 700)
# 90 371
# 90 371
# 90 371
# (1, 700)
# (1, 700)
# (1, 700)
# 199 427
# 199 427
# 199 427
# (1, 700)
# (1, 700)
# (1, 700)
# 261 635
# 261 635
# 261 635
# (1, 700)
# (1, 700)
# (1, 700)
# 463 615
# 463 615
# 463 615

# %%
total_epochs = 150

# %%
history = model.fit(
    DataGenerator(trainX,trainAttm,trainPosIds,trainY,len_shift_train,batch_size=20,shuffle=True),
    epochs=total_epochs,
    verbose=1,
    validation_data=DataGenerator(validationX,validationAttm,validationPosIds,validationY,len_shift_validation,batch_size=16,shuffle=False),
    # validation_batch_size = 8,
    shuffle=True,
    workers = -1,
    callbacks=[lr_callback, es_callback, cp_callback]
)
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/keras/backend/tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Epoch 1/150
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-07.
# 502/502 [==============================] - 378s 753ms/step - loss: 12.5489 - truncated_accuracy: 0.1301 - accuracy: 0.1035 - mae: 0.1544 - val_loss: 12.2559 - val_truncated_accuracy: 0.1107 - val_accuracy: 0.0614 - val_mae: 0.1544
#
# Epoch 00001: val_truncated_accuracy improved from -inf to 0.11071, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.110712.hdf5
# Epoch 2/150
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.00010009.
# 502/502 [==============================] - 321s 640ms/step - loss: 9.9647 - truncated_accuracy: 0.4530 - accuracy: 0.2033 - mae: 0.1355 - val_loss: 7.8822 - val_truncated_accuracy: 0.6064 - val_accuracy: 0.2476 - val_mae: 0.1237
#
# Epoch 00002: val_truncated_accuracy improved from 0.11071 to 0.60643, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.606434.hdf5
# Epoch 3/150
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.00020008.
# 502/502 [==============================] - 321s 640ms/step - loss: 5.5358 - truncated_accuracy: 0.6408 - accuracy: 0.3445 - mae: 0.1223 - val_loss: 3.6873 - val_truncated_accuracy: 0.6648 - val_accuracy: 0.2884 - val_mae: 0.1235
#
# Epoch 00003: val_truncated_accuracy improved from 0.60643 to 0.66482, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.664821.hdf5
# Epoch 4/150
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.00030007.
# 502/502 [==============================] - 321s 640ms/step - loss: 2.4159 - truncated_accuracy: 0.6843 - accuracy: 0.3875 - mae: 0.1185 - val_loss: 1.4663 - val_truncated_accuracy: 0.6920 - val_accuracy: 0.4332 - val_mae: 0.1211
#
# Epoch 00004: val_truncated_accuracy improved from 0.66482 to 0.69197, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.691974.hdf5
# Epoch 5/150
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.00040006.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.9903 - truncated_accuracy: 0.7041 - accuracy: 0.3854 - mae: 0.1166 - val_loss: 0.5827 - val_truncated_accuracy: 0.7085 - val_accuracy: 0.3559 - val_mae: 0.1185
#
# Epoch 00005: val_truncated_accuracy improved from 0.69197 to 0.70851, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.708507.hdf5
# Epoch 6/150
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0005000499999999999.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4795 - truncated_accuracy: 0.7113 - accuracy: 0.4020 - mae: 0.1160 - val_loss: 0.3160 - val_truncated_accuracy: 0.7142 - val_accuracy: 0.4587 - val_mae: 0.1180
#
# Epoch 00006: val_truncated_accuracy improved from 0.70851 to 0.71415, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.714150.hdf5
# Epoch 7/150
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0006000399999999999.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3484 - truncated_accuracy: 0.7117 - accuracy: 0.4155 - mae: 0.1160 - val_loss: 0.5453 - val_truncated_accuracy: 0.5816 - val_accuracy: 0.2210 - val_mae: 0.1270
#
# Epoch 00007: val_truncated_accuracy did not improve from 0.71415
# Epoch 8/150
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0007000299999999999.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4274 - truncated_accuracy: 0.7071 - accuracy: 0.4550 - mae: 0.1164 - val_loss: 0.2993 - val_truncated_accuracy: 0.7057 - val_accuracy: 0.4211 - val_mae: 0.1195
#
# Epoch 00008: val_truncated_accuracy did not improve from 0.71415
# Epoch 9/150
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0008000199999999999.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3960 - truncated_accuracy: 0.7038 - accuracy: 0.4543 - mae: 0.1168 - val_loss: 0.3083 - val_truncated_accuracy: 0.6916 - val_accuracy: 0.4778 - val_mae: 0.1204
#
# Epoch 00009: val_truncated_accuracy did not improve from 0.71415
# Epoch 10/150
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0009000099999999999.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3996 - truncated_accuracy: 0.7023 - accuracy: 0.4653 - mae: 0.1169 - val_loss: 0.3498 - val_truncated_accuracy: 0.6892 - val_accuracy: 0.5541 - val_mae: 0.1220
#
# Epoch 00010: val_truncated_accuracy did not improve from 0.71415
# Epoch 11/150
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.001.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4967 - truncated_accuracy: 0.6991 - accuracy: 0.4761 - mae: 0.1172 - val_loss: 0.5194 - val_truncated_accuracy: 0.6269 - val_accuracy: 0.4557 - val_mae: 0.1234
#
# Epoch 00011: val_truncated_accuracy did not improve from 0.71415
# Epoch 12/150
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009604.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.9045 - truncated_accuracy: 0.6790 - accuracy: 0.5921 - mae: 0.1192 - val_loss: 0.5548 - val_truncated_accuracy: 0.6604 - val_accuracy: 0.6985 - val_mae: 0.1252
#
# Epoch 00012: val_truncated_accuracy did not improve from 0.71415
# Epoch 13/150
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009223839999999999.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4878 - truncated_accuracy: 0.7004 - accuracy: 0.5489 - mae: 0.1171 - val_loss: 0.5282 - val_truncated_accuracy: 0.5846 - val_accuracy: 0.1930 - val_mae: 0.1231
#
# Epoch 00013: val_truncated_accuracy did not improve from 0.71415
# Epoch 14/150
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0008858886399999999.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.8489 - truncated_accuracy: 0.6923 - accuracy: 0.5545 - mae: 0.1179 - val_loss: 1.0910 - val_truncated_accuracy: 0.6255 - val_accuracy: 0.2476 - val_mae: 0.1222
#
# Epoch 00014: val_truncated_accuracy did not improve from 0.71415
# Epoch 15/150
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0008508530943999999.
# 502/502 [==============================] - 321s 640ms/step - loss: 1.0304 - truncated_accuracy: 0.6987 - accuracy: 0.5518 - mae: 0.1173 - val_loss: 0.8141 - val_truncated_accuracy: 0.6885 - val_accuracy: 0.7208 - val_mae: 0.1197
#
# Epoch 00015: val_truncated_accuracy did not improve from 0.71415
# Epoch 16/150
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0008172189706239999.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.8883 - truncated_accuracy: 0.6958 - accuracy: 0.6016 - mae: 0.1176 - val_loss: 0.9805 - val_truncated_accuracy: 0.5990 - val_accuracy: 0.2277 - val_mae: 0.1231
#
# Epoch 00016: val_truncated_accuracy did not improve from 0.71415
# Epoch 17/150
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0007849302117990399.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.7816 - truncated_accuracy: 0.7011 - accuracy: 0.5888 - mae: 0.1170 - val_loss: 2.3449 - val_truncated_accuracy: 0.3125 - val_accuracy: 0.2187 - val_mae: 0.1419
#
# Epoch 00017: val_truncated_accuracy did not improve from 0.71415
# Epoch 18/150
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0007539330033270782.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.6390 - truncated_accuracy: 0.7019 - accuracy: 0.5693 - mae: 0.1169 - val_loss: 0.6321 - val_truncated_accuracy: 0.6869 - val_accuracy: 0.5106 - val_mae: 0.1188
#
# Epoch 00018: val_truncated_accuracy did not improve from 0.71415
# Epoch 19/150
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.000724175683193995.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.7183 - truncated_accuracy: 0.7060 - accuracy: 0.5943 - mae: 0.1165 - val_loss: 0.6109 - val_truncated_accuracy: 0.7076 - val_accuracy: 0.6677 - val_mae: 0.1168
#
# Epoch 00019: val_truncated_accuracy did not improve from 0.71415
# Epoch 20/150
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0006956086558662352.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.6428 - truncated_accuracy: 0.7040 - accuracy: 0.5507 - mae: 0.1167 - val_loss: 1.1495 - val_truncated_accuracy: 0.2946 - val_accuracy: 0.1602 - val_mae: 0.1425
#
# Epoch 00020: val_truncated_accuracy did not improve from 0.71415
# Epoch 21/150
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0006681843096315858.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.7119 - truncated_accuracy: 0.7071 - accuracy: 0.6059 - mae: 0.1164 - val_loss: 0.5864 - val_truncated_accuracy: 0.7064 - val_accuracy: 0.7165 - val_mae: 0.1163
#
# Epoch 00021: val_truncated_accuracy did not improve from 0.71415
# Epoch 22/150
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0006418569372463224.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.7623 - truncated_accuracy: 0.7003 - accuracy: 0.6056 - mae: 0.1172 - val_loss: 2.3031 - val_truncated_accuracy: 0.3552 - val_accuracy: 0.1371 - val_mae: 0.1369
#
# Epoch 00022: val_truncated_accuracy did not improve from 0.71415
# Epoch 23/150
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0006165826597564695.
# 502/502 [==============================] - 321s 640ms/step - loss: 1.1585 - truncated_accuracy: 0.6951 - accuracy: 0.5932 - mae: 0.1176 - val_loss: 0.8514 - val_truncated_accuracy: 0.7069 - val_accuracy: 0.6292 - val_mae: 0.1200
#
# Epoch 00023: val_truncated_accuracy did not improve from 0.71415
# Epoch 24/150
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0005923193533662106.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.7859 - truncated_accuracy: 0.7080 - accuracy: 0.5989 - mae: 0.1164 - val_loss: 0.6511 - val_truncated_accuracy: 0.7088 - val_accuracy: 0.7749 - val_mae: 0.1182
#
# Epoch 00024: val_truncated_accuracy did not improve from 0.71415
# Epoch 25/150
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0005690265792315622.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.6403 - truncated_accuracy: 0.7112 - accuracy: 0.6449 - mae: 0.1161 - val_loss: 0.5608 - val_truncated_accuracy: 0.7131 - val_accuracy: 0.7046 - val_mae: 0.1155
#
# Epoch 00025: val_truncated_accuracy did not improve from 0.71415
# Epoch 26/150
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0005466655160622998.
# 502/502 [==============================] - 321s 639ms/step - loss: 0.5991 - truncated_accuracy: 0.7111 - accuracy: 0.6776 - mae: 0.1161 - val_loss: 0.5484 - val_truncated_accuracy: 0.7156 - val_accuracy: 0.6771 - val_mae: 0.1167
#
# Epoch 00026: val_truncated_accuracy improved from 0.71415 to 0.71557, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.715565.hdf5
# Epoch 27/150
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0005251988954198077.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5699 - truncated_accuracy: 0.7145 - accuracy: 0.6589 - mae: 0.1157 - val_loss: 0.4702 - val_truncated_accuracy: 0.7168 - val_accuracy: 0.8976 - val_mae: 0.1167
#
# Epoch 00027: val_truncated_accuracy improved from 0.71557 to 0.71684, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.716841.hdf5
# Epoch 28/150
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0005045909396030154.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4949 - truncated_accuracy: 0.7136 - accuracy: 0.6344 - mae: 0.1158 - val_loss: 0.4935 - val_truncated_accuracy: 0.6827 - val_accuracy: 0.3472 - val_mae: 0.1154
#
# Epoch 00028: val_truncated_accuracy did not improve from 0.71684
# Epoch 29/150
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0004848073020188947.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.6329 - truncated_accuracy: 0.7091 - accuracy: 0.6304 - mae: 0.1163 - val_loss: 0.7359 - val_truncated_accuracy: 0.7097 - val_accuracy: 0.7964 - val_mae: 0.1177
#
# Epoch 00029: val_truncated_accuracy did not improve from 0.71684
# Epoch 30/150
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0004658150099381389.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.7482 - truncated_accuracy: 0.7162 - accuracy: 0.6626 - mae: 0.1156 - val_loss: 0.6272 - val_truncated_accuracy: 0.7220 - val_accuracy: 0.7722 - val_mae: 0.1161
#
# Epoch 00030: val_truncated_accuracy improved from 0.71684 to 0.72201, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.722006.hdf5
# Epoch 31/150
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.00044758240954061336.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.6319 - truncated_accuracy: 0.7194 - accuracy: 0.6717 - mae: 0.1152 - val_loss: 0.5619 - val_truncated_accuracy: 0.7195 - val_accuracy: 0.9018 - val_mae: 0.1156
#
# Epoch 00031: val_truncated_accuracy did not improve from 0.72201
# Epoch 32/150
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0004300791131589888.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5835 - truncated_accuracy: 0.7201 - accuracy: 0.7018 - mae: 0.1152 - val_loss: 0.5048 - val_truncated_accuracy: 0.7206 - val_accuracy: 0.7752 - val_mae: 0.1159
#
# Epoch 00032: val_truncated_accuracy did not improve from 0.72201
# Epoch 33/150
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0004132759486326292.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5355 - truncated_accuracy: 0.7187 - accuracy: 0.6789 - mae: 0.1153 - val_loss: 0.4309 - val_truncated_accuracy: 0.7252 - val_accuracy: 0.6528 - val_mae: 0.1164
#
# Epoch 00033: val_truncated_accuracy improved from 0.72201 to 0.72516, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.725157.hdf5
# Epoch 34/150
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.00039714491068732405.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.4860 - truncated_accuracy: 0.7203 - accuracy: 0.6517 - mae: 0.1152 - val_loss: 0.4461 - val_truncated_accuracy: 0.7253 - val_accuracy: 0.7435 - val_mae: 0.1151
#
# Epoch 00034: val_truncated_accuracy improved from 0.72516 to 0.72530, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.725304.hdf5
# Epoch 35/150
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0003816591142598311.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.4766 - truncated_accuracy: 0.7232 - accuracy: 0.6662 - mae: 0.1149 - val_loss: 0.3857 - val_truncated_accuracy: 0.7273 - val_accuracy: 0.7927 - val_mae: 0.1151
#
# Epoch 00035: val_truncated_accuracy improved from 0.72530 to 0.72732, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.727321.hdf5
# Epoch 36/150
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0003667927496894378.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.4439 - truncated_accuracy: 0.7235 - accuracy: 0.6497 - mae: 0.1148 - val_loss: 1.6097 - val_truncated_accuracy: 0.2907 - val_accuracy: 0.0930 - val_mae: 0.1413
#
# Epoch 00036: val_truncated_accuracy did not improve from 0.72732
# Epoch 37/150
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0003525210397018603.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4909 - truncated_accuracy: 0.7241 - accuracy: 0.6702 - mae: 0.1148 - val_loss: 0.4320 - val_truncated_accuracy: 0.7256 - val_accuracy: 0.8354 - val_mae: 0.1148
#
# Epoch 00037: val_truncated_accuracy did not improve from 0.72732
# Epoch 38/150
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0003388201981137859.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5103 - truncated_accuracy: 0.7246 - accuracy: 0.6745 - mae: 0.1148 - val_loss: 0.4845 - val_truncated_accuracy: 0.7307 - val_accuracy: 0.7474 - val_mae: 0.1149
#
# Epoch 00038: val_truncated_accuracy improved from 0.72732 to 0.73067, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.730669.hdf5
# Epoch 39/150
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.00032566739018923446.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5394 - truncated_accuracy: 0.7250 - accuracy: 0.6425 - mae: 0.1147 - val_loss: 0.4664 - val_truncated_accuracy: 0.7298 - val_accuracy: 0.6496 - val_mae: 0.1143
#
# Epoch 00039: val_truncated_accuracy did not improve from 0.73067
# Epoch 40/150
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.000313040694581665.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5080 - truncated_accuracy: 0.7280 - accuracy: 0.6357 - mae: 0.1144 - val_loss: 0.4532 - val_truncated_accuracy: 0.7286 - val_accuracy: 0.7666 - val_mae: 0.1146
#
# Epoch 00040: val_truncated_accuracy did not improve from 0.73067
# Epoch 41/150
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.00030091906679839843.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5204 - truncated_accuracy: 0.7279 - accuracy: 0.6459 - mae: 0.1144 - val_loss: 0.4551 - val_truncated_accuracy: 0.7328 - val_accuracy: 0.7496 - val_mae: 0.1142
#
# Epoch 00041: val_truncated_accuracy improved from 0.73067 to 0.73276, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.732756.hdf5
# Epoch 42/150
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0002892823041264625.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.5633 - truncated_accuracy: 0.7139 - accuracy: 0.6693 - mae: 0.1158 - val_loss: 0.5297 - val_truncated_accuracy: 0.7176 - val_accuracy: 0.7716 - val_mae: 0.1149
#
# Epoch 00042: val_truncated_accuracy did not improve from 0.73276
# Epoch 43/150
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.000278111011961404.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5556 - truncated_accuracy: 0.7192 - accuracy: 0.6772 - mae: 0.1153 - val_loss: 0.4614 - val_truncated_accuracy: 0.7275 - val_accuracy: 0.7456 - val_mae: 0.1149
#
# Epoch 00043: val_truncated_accuracy did not improve from 0.73276
# Epoch 44/150
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0002673865714829478.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.5117 - truncated_accuracy: 0.7246 - accuracy: 0.6702 - mae: 0.1147 - val_loss: 0.4512 - val_truncated_accuracy: 0.7220 - val_accuracy: 0.6335 - val_mae: 0.1140
#
# Epoch 00044: val_truncated_accuracy did not improve from 0.73276
# Epoch 45/150
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0002570911086236299.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4951 - truncated_accuracy: 0.7265 - accuracy: 0.6497 - mae: 0.1146 - val_loss: 0.4231 - val_truncated_accuracy: 0.7327 - val_accuracy: 0.6623 - val_mae: 0.1144
#
# Epoch 00045: val_truncated_accuracy did not improve from 0.73276
# Epoch 46/150
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.00024720746427868466.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4694 - truncated_accuracy: 0.7310 - accuracy: 0.6673 - mae: 0.1141 - val_loss: 0.4001 - val_truncated_accuracy: 0.7331 - val_accuracy: 0.6736 - val_mae: 0.1141
#
# Epoch 00046: val_truncated_accuracy improved from 0.73276 to 0.73313, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.733126.hdf5
# Epoch 47/150
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.00023771916570753724.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.4481 - truncated_accuracy: 0.7325 - accuracy: 0.6688 - mae: 0.1140 - val_loss: 0.3758 - val_truncated_accuracy: 0.7352 - val_accuracy: 0.6422 - val_mae: 0.1138
#
# Epoch 00047: val_truncated_accuracy improved from 0.73313 to 0.73524, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.735244.hdf5
# Epoch 48/150
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.00022861039907923574.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.4361 - truncated_accuracy: 0.7336 - accuracy: 0.6644 - mae: 0.1139 - val_loss: 0.3716 - val_truncated_accuracy: 0.7364 - val_accuracy: 0.7342 - val_mae: 0.1138
#
# Epoch 00048: val_truncated_accuracy improved from 0.73524 to 0.73643, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.736434.hdf5
# Epoch 49/150
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.00021986598311606634.
# 502/502 [==============================] - 322s 640ms/step - loss: 0.4290 - truncated_accuracy: 0.7338 - accuracy: 0.6803 - mae: 0.1138 - val_loss: 0.3577 - val_truncated_accuracy: 0.7372 - val_accuracy: 0.7306 - val_mae: 0.1138
#
# Epoch 00049: val_truncated_accuracy improved from 0.73643 to 0.73720, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.737199.hdf5
# Epoch 50/150
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.00021147134379142366.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.4069 - truncated_accuracy: 0.7354 - accuracy: 0.6706 - mae: 0.1137 - val_loss: 0.3361 - val_truncated_accuracy: 0.7374 - val_accuracy: 0.7777 - val_mae: 0.1136
#
# Epoch 00050: val_truncated_accuracy improved from 0.73720 to 0.73744, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.737443.hdf5
# Epoch 51/150
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.00020341249003976672.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3960 - truncated_accuracy: 0.7363 - accuracy: 0.7006 - mae: 0.1136 - val_loss: 0.3290 - val_truncated_accuracy: 0.7379 - val_accuracy: 0.7357 - val_mae: 0.1139
#
# Epoch 00051: val_truncated_accuracy improved from 0.73744 to 0.73788, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.737879.hdf5
# Epoch 52/150
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.00019567599043817605.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3825 - truncated_accuracy: 0.7371 - accuracy: 0.6700 - mae: 0.1135 - val_loss: 0.3247 - val_truncated_accuracy: 0.7404 - val_accuracy: 0.6741 - val_mae: 0.1134
#
# Epoch 00052: val_truncated_accuracy improved from 0.73788 to 0.74043, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.740429.hdf5
# Epoch 53/150
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.00018824895082064899.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3859 - truncated_accuracy: 0.7373 - accuracy: 0.6624 - mae: 0.1135 - val_loss: 0.3211 - val_truncated_accuracy: 0.7406 - val_accuracy: 0.6923 - val_mae: 0.1134
#
# Epoch 00053: val_truncated_accuracy improved from 0.74043 to 0.74064, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.740636.hdf5
# Epoch 54/150
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.00018111899278782303.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3716 - truncated_accuracy: 0.7391 - accuracy: 0.6768 - mae: 0.1133 - val_loss: 0.3038 - val_truncated_accuracy: 0.7409 - val_accuracy: 0.7746 - val_mae: 0.1131
#
# Epoch 00054: val_truncated_accuracy improved from 0.74064 to 0.74088, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.740881.hdf5
# Epoch 55/150
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0001742742330763101.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3645 - truncated_accuracy: 0.7374 - accuracy: 0.6932 - mae: 0.1135 - val_loss: 0.3033 - val_truncated_accuracy: 0.7407 - val_accuracy: 0.7487 - val_mae: 0.1133
#
# Epoch 00055: val_truncated_accuracy did not improve from 0.74088
# Epoch 56/150
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.00016770326375325768.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3646 - truncated_accuracy: 0.7394 - accuracy: 0.6914 - mae: 0.1133 - val_loss: 0.3021 - val_truncated_accuracy: 0.7418 - val_accuracy: 0.7666 - val_mae: 0.1130
#
# Epoch 00056: val_truncated_accuracy improved from 0.74088 to 0.74184, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.741841.hdf5
# Epoch 57/150
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.00016139513320312737.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3636 - truncated_accuracy: 0.7404 - accuracy: 0.6812 - mae: 0.1132 - val_loss: 0.3069 - val_truncated_accuracy: 0.7428 - val_accuracy: 0.6927 - val_mae: 0.1128
#
# Epoch 00057: val_truncated_accuracy improved from 0.74184 to 0.74275, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.742752.hdf5
# Epoch 58/150
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0001553393278750023.
# 502/502 [==============================] - 322s 640ms/step - loss: 0.3665 - truncated_accuracy: 0.7409 - accuracy: 0.6828 - mae: 0.1131 - val_loss: 0.3102 - val_truncated_accuracy: 0.7433 - val_accuracy: 0.7491 - val_mae: 0.1130
#
# Epoch 00058: val_truncated_accuracy improved from 0.74275 to 0.74332, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.743324.hdf5
# Epoch 59/150
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.00014952575476000218.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3725 - truncated_accuracy: 0.7369 - accuracy: 0.6720 - mae: 0.1135 - val_loss: 0.3067 - val_truncated_accuracy: 0.7410 - val_accuracy: 0.6861 - val_mae: 0.1131
#
# Epoch 00059: val_truncated_accuracy did not improve from 0.74332
# Epoch 60/150
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0001439447245696021.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3599 - truncated_accuracy: 0.7421 - accuracy: 0.6679 - mae: 0.1130 - val_loss: 0.2967 - val_truncated_accuracy: 0.7430 - val_accuracy: 0.7258 - val_mae: 0.1128
#
# Epoch 00060: val_truncated_accuracy did not improve from 0.74332
# Epoch 61/150
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.000138586935586818.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3506 - truncated_accuracy: 0.7430 - accuracy: 0.6785 - mae: 0.1129 - val_loss: 0.2968 - val_truncated_accuracy: 0.7445 - val_accuracy: 0.6677 - val_mae: 0.1127
#
# Epoch 00061: val_truncated_accuracy improved from 0.74332 to 0.74449, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.744494.hdf5
# Epoch 62/150
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.00013344345816334528.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3526 - truncated_accuracy: 0.7439 - accuracy: 0.6751 - mae: 0.1128 - val_loss: 0.2938 - val_truncated_accuracy: 0.7451 - val_accuracy: 0.7604 - val_mae: 0.1128
#
# Epoch 00062: val_truncated_accuracy improved from 0.74449 to 0.74511, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.745105.hdf5
# Epoch 63/150
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.00012850571983681147.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3453 - truncated_accuracy: 0.7446 - accuracy: 0.6701 - mae: 0.1128 - val_loss: 0.2902 - val_truncated_accuracy: 0.7458 - val_accuracy: 0.6896 - val_mae: 0.1126
#
# Epoch 00063: val_truncated_accuracy improved from 0.74511 to 0.74577, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.745769.hdf5
# Epoch 64/150
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.000123765491043339.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3417 - truncated_accuracy: 0.7453 - accuracy: 0.6769 - mae: 0.1127 - val_loss: 0.2876 - val_truncated_accuracy: 0.7452 - val_accuracy: 0.7472 - val_mae: 0.1124
#
# Epoch 00064: val_truncated_accuracy did not improve from 0.74577
# Epoch 65/150
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.00011921487140160543.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3410 - truncated_accuracy: 0.7458 - accuracy: 0.6732 - mae: 0.1127 - val_loss: 0.2849 - val_truncated_accuracy: 0.7473 - val_accuracy: 0.7190 - val_mae: 0.1127
#
# Epoch 00065: val_truncated_accuracy improved from 0.74577 to 0.74732, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.747324.hdf5
# Epoch 66/150
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0001148462765455412.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3374 - truncated_accuracy: 0.7465 - accuracy: 0.6911 - mae: 0.1126 - val_loss: 0.2779 - val_truncated_accuracy: 0.7471 - val_accuracy: 0.7728 - val_mae: 0.1121
#
# Epoch 00066: val_truncated_accuracy did not improve from 0.74732
# Epoch 67/150
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.00011065242548371957.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.3316 - truncated_accuracy: 0.7467 - accuracy: 0.6921 - mae: 0.1126 - val_loss: 0.2755 - val_truncated_accuracy: 0.7471 - val_accuracy: 0.7302 - val_mae: 0.1123
#
# Epoch 00067: val_truncated_accuracy did not improve from 0.74732
# Epoch 68/150
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.00010662632846437077.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3295 - truncated_accuracy: 0.7467 - accuracy: 0.6828 - mae: 0.1126 - val_loss: 0.2727 - val_truncated_accuracy: 0.7469 - val_accuracy: 0.7585 - val_mae: 0.1124
#
# Epoch 00068: val_truncated_accuracy did not improve from 0.74732
# Epoch 69/150
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.00010276127532579594.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3288 - truncated_accuracy: 0.7466 - accuracy: 0.6661 - mae: 0.1126 - val_loss: 0.2697 - val_truncated_accuracy: 0.7481 - val_accuracy: 0.7469 - val_mae: 0.1122
#
# Epoch 00069: val_truncated_accuracy improved from 0.74732 to 0.74814, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.748136.hdf5
# Epoch 70/150
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 9.905082431276409e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3236 - truncated_accuracy: 0.7482 - accuracy: 0.6804 - mae: 0.1124 - val_loss: 0.2675 - val_truncated_accuracy: 0.7488 - val_accuracy: 0.7393 - val_mae: 0.1121
#
# Epoch 00070: val_truncated_accuracy improved from 0.74814 to 0.74876, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.748758.hdf5
# Epoch 71/150
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 9.548879134025353e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3184 - truncated_accuracy: 0.7490 - accuracy: 0.6728 - mae: 0.1123 - val_loss: 0.2653 - val_truncated_accuracy: 0.7487 - val_accuracy: 0.7608 - val_mae: 0.1122
#
# Epoch 00071: val_truncated_accuracy did not improve from 0.74876
# Epoch 72/150
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 9.206923968664338e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3141 - truncated_accuracy: 0.7494 - accuracy: 0.6964 - mae: 0.1123 - val_loss: 0.2611 - val_truncated_accuracy: 0.7491 - val_accuracy: 0.7178 - val_mae: 0.1120
#
# Epoch 00072: val_truncated_accuracy improved from 0.74876 to 0.74909, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.749093.hdf5
# Epoch 73/150
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 8.878647009917764e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3129 - truncated_accuracy: 0.7494 - accuracy: 0.6997 - mae: 0.1123 - val_loss: 0.2545 - val_truncated_accuracy: 0.7500 - val_accuracy: 0.7646 - val_mae: 0.1120
#
# Epoch 00073: val_truncated_accuracy improved from 0.74909 to 0.74999, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.749994.hdf5
# Epoch 74/150
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 8.563501129521054e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3072 - truncated_accuracy: 0.7508 - accuracy: 0.7077 - mae: 0.1122 - val_loss: 0.2523 - val_truncated_accuracy: 0.7492 - val_accuracy: 0.6479 - val_mae: 0.1119
#
# Epoch 00074: val_truncated_accuracy did not improve from 0.74999
# Epoch 75/150
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 8.260961084340211e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3037 - truncated_accuracy: 0.7510 - accuracy: 0.6923 - mae: 0.1121 - val_loss: 0.2503 - val_truncated_accuracy: 0.7501 - val_accuracy: 0.7282 - val_mae: 0.1118
#
# Epoch 00075: val_truncated_accuracy improved from 0.74999 to 0.75012, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.750116.hdf5
# Epoch 76/150
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 7.970522640966602e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3010 - truncated_accuracy: 0.7521 - accuracy: 0.6906 - mae: 0.1121 - val_loss: 0.2451 - val_truncated_accuracy: 0.7504 - val_accuracy: 0.7425 - val_mae: 0.1117
#
# Epoch 00076: val_truncated_accuracy improved from 0.75012 to 0.75043, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.750427.hdf5
# Epoch 77/150
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 7.691701735327939e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.3025 - truncated_accuracy: 0.7491 - accuracy: 0.6992 - mae: 0.1123 - val_loss: 0.2483 - val_truncated_accuracy: 0.7488 - val_accuracy: 0.7762 - val_mae: 0.1119
#
# Epoch 00077: val_truncated_accuracy did not improve from 0.75043
# Epoch 78/150
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 7.424033665914821e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2967 - truncated_accuracy: 0.7521 - accuracy: 0.7015 - mae: 0.1120 - val_loss: 0.2419 - val_truncated_accuracy: 0.7501 - val_accuracy: 0.7631 - val_mae: 0.1116
#
# Epoch 00078: val_truncated_accuracy did not improve from 0.75043
# Epoch 79/150
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 7.167072319278228e-05.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.2918 - truncated_accuracy: 0.7533 - accuracy: 0.7116 - mae: 0.1119 - val_loss: 0.2395 - val_truncated_accuracy: 0.7507 - val_accuracy: 0.7692 - val_mae: 0.1118
#
# Epoch 00079: val_truncated_accuracy improved from 0.75043 to 0.75074, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.750744.hdf5
# Epoch 80/150
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 6.920389426507099e-05.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.2912 - truncated_accuracy: 0.7535 - accuracy: 0.7076 - mae: 0.1119 - val_loss: 0.2372 - val_truncated_accuracy: 0.7513 - val_accuracy: 0.7628 - val_mae: 0.1117
#
# Epoch 00080: val_truncated_accuracy improved from 0.75074 to 0.75129, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.751289.hdf5
# Epoch 81/150
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 6.683573849446814e-05.
# 502/502 [==============================] - 321s 640ms/step - loss: 0.2911 - truncated_accuracy: 0.7538 - accuracy: 0.6991 - mae: 0.1119 - val_loss: 0.2369 - val_truncated_accuracy: 0.7520 - val_accuracy: 0.7621 - val_mae: 0.1116
#
# Epoch 00081: val_truncated_accuracy improved from 0.75129 to 0.75201, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.752012.hdf5
# Epoch 82/150
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 6.456230895468941e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2903 - truncated_accuracy: 0.7540 - accuracy: 0.6989 - mae: 0.1118 - val_loss: 0.2393 - val_truncated_accuracy: 0.7512 - val_accuracy: 0.7561 - val_mae: 0.1116
#
# Epoch 00082: val_truncated_accuracy did not improve from 0.75201
# Epoch 83/150
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 6.237981659650184e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2880 - truncated_accuracy: 0.7547 - accuracy: 0.7103 - mae: 0.1118 - val_loss: 0.2352 - val_truncated_accuracy: 0.7519 - val_accuracy: 0.7783 - val_mae: 0.1116
#
# Epoch 00083: val_truncated_accuracy did not improve from 0.75201
# Epoch 84/150
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 6.028462393264176e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2865 - truncated_accuracy: 0.7553 - accuracy: 0.7018 - mae: 0.1117 - val_loss: 0.2333 - val_truncated_accuracy: 0.7512 - val_accuracy: 0.7555 - val_mae: 0.1116
#
# Epoch 00084: val_truncated_accuracy did not improve from 0.75201
# Epoch 85/150
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 5.8273238975336084e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2859 - truncated_accuracy: 0.7552 - accuracy: 0.6954 - mae: 0.1117 - val_loss: 0.2326 - val_truncated_accuracy: 0.7525 - val_accuracy: 0.7695 - val_mae: 0.1114
#
# Epoch 00085: val_truncated_accuracy improved from 0.75201 to 0.75251, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.752508.hdf5
# Epoch 86/150
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 5.6342309416322645e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2841 - truncated_accuracy: 0.7558 - accuracy: 0.6914 - mae: 0.1117 - val_loss: 0.2312 - val_truncated_accuracy: 0.7527 - val_accuracy: 0.7569 - val_mae: 0.1115
#
# Epoch 00086: val_truncated_accuracy improved from 0.75251 to 0.75272, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.752721.hdf5
# Epoch 87/150
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 5.4488617039669736e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2819 - truncated_accuracy: 0.7564 - accuracy: 0.6998 - mae: 0.1116 - val_loss: 0.2290 - val_truncated_accuracy: 0.7535 - val_accuracy: 0.7646 - val_mae: 0.1114
#
# Epoch 00087: val_truncated_accuracy improved from 0.75272 to 0.75353, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.753527.hdf5
# Epoch 88/150
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 5.2709072358082945e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2808 - truncated_accuracy: 0.7567 - accuracy: 0.6993 - mae: 0.1115 - val_loss: 0.2268 - val_truncated_accuracy: 0.7532 - val_accuracy: 0.7872 - val_mae: 0.1112
#
# Epoch 00088: val_truncated_accuracy did not improve from 0.75353
# Epoch 89/150
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 5.1000709463759625e-05.
# 502/502 [==============================] - 322s 641ms/step - loss: 0.2797 - truncated_accuracy: 0.7570 - accuracy: 0.7039 - mae: 0.1115 - val_loss: 0.2287 - val_truncated_accuracy: 0.7525 - val_accuracy: 0.7655 - val_mae: 0.1114
#
# Epoch 00089: val_truncated_accuracy did not improve from 0.75353
# Epoch 90/150
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 4.9360681085209236e-05.
# 502/502 [==============================] - 322s 642ms/step - loss: 0.2785 - truncated_accuracy: 0.7573 - accuracy: 0.7021 - mae: 0.1115 - val_loss: 0.2285 - val_truncated_accuracy: 0.7533 - val_accuracy: 0.7730 - val_mae: 0.1113
#
# Epoch 00090: val_truncated_accuracy did not improve from 0.75353
# Epoch 91/150
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 4.7786253841800864e-05.
# 502/502 [==============================] - 322s 642ms/step - loss: 0.2796 - truncated_accuracy: 0.7560 - accuracy: 0.7046 - mae: 0.1116 - val_loss: 0.2283 - val_truncated_accuracy: 0.7535 - val_accuracy: 0.7838 - val_mae: 0.1113
#
# Epoch 00091: val_truncated_accuracy did not improve from 0.75353
# Epoch 92/150
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 4.627480368812883e-05.
# 502/502 [==============================] - 322s 642ms/step - loss: 0.2773 - truncated_accuracy: 0.7575 - accuracy: 0.7109 - mae: 0.1115 - val_loss: 0.2280 - val_truncated_accuracy: 0.7531 - val_accuracy: 0.7684 - val_mae: 0.1112
#
# Epoch 00092: val_truncated_accuracy did not improve from 0.75353
# Epoch 93/150
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 4.4823811540603674e-05.
# 502/502 [==============================] - 323s 643ms/step - loss: 0.2757 - truncated_accuracy: 0.7583 - accuracy: 0.7076 - mae: 0.1114 - val_loss: 0.2268 - val_truncated_accuracy: 0.7534 - val_accuracy: 0.7684 - val_mae: 0.1112
#
# Epoch 00093: val_truncated_accuracy did not improve from 0.75353
# Epoch 94/150
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 4.3430859078979526e-05.
# 502/502 [==============================] - 322s 642ms/step - loss: 0.2745 - truncated_accuracy: 0.7587 - accuracy: 0.6990 - mae: 0.1114 - val_loss: 0.2236 - val_truncated_accuracy: 0.7538 - val_accuracy: 0.7646 - val_mae: 0.1111
#
# Epoch 00094: val_truncated_accuracy improved from 0.75353 to 0.75382, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.753817.hdf5
# Epoch 95/150
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 4.2093624715820346e-05.
# 502/502 [==============================] - 322s 642ms/step - loss: 0.2733 - truncated_accuracy: 0.7588 - accuracy: 0.6947 - mae: 0.1113 - val_loss: 0.2223 - val_truncated_accuracy: 0.7547 - val_accuracy: 0.7447 - val_mae: 0.1112
#
# Epoch 00095: val_truncated_accuracy improved from 0.75382 to 0.75473, saving model to /content/drive/MyDrive/bio-data/AN2-saint-base-build-MHA-2-DataGen-CLB-FinalRun-1/best-0.754733.hdf5
# Epoch 96/150
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 4.080987972718753e-05.
#  52/502 [==>...........................] - ETA: 4:41 - loss: 0.2757 - truncated_accuracy: 0.7593 - accuracy: 0.6769 - mae: 0.1111

# %% [markdown]
# **Inference**

# %%
data_name = 'validation'
predX = np.load('/content/drive/MyDrive/bio-data/'+data_name+'X.npy')
print(predX.shape)
predY = np.load('/content/drive/MyDrive/bio-data/'+data_name+'Y.npy')[:,:,:8]
print(predY.shape)
predAttm = np.load('/content/drive/MyDrive/bio-data/'+data_name+'AttM.npy')
print(predAttm.shape)
predPosIds = np.array(range(700))
predPosIds = np.repeat([predPosIds], int(predX.shape[0]), axis=0)
print(predPosIds.shape)
# Out:
# (983, 700, 57)
# (983, 700, 8)
# (983, 700)
# (983, 700)

# %%
predictions = model.predict([predX,predAttm,predPosIds],verbose = 1)
# Out:
# 1213/1213 [==============================] - 11s 9ms/step

# %%
def check_pred(y_true,y_predict):
    mask = np.sum(y_true, axis=2)
    y_pred_labels = np.argmax(y_predict, axis=2).astype(np.float32)
    y_true_labels = np.argmax(y_true, axis=2).astype(np.float32)
    print('ok')
    is_same = np.equal(
        y_true_labels, y_pred_labels)
    num_same = np.sum(is_same * mask, axis=1)
    lengths = np.sum(mask, axis=1)
    return (lambda x: x[0]/x[1])([np.sum(num_same, axis=0), np.sum(lengths, axis=0)])
    # return K.cast(K.sum(num_same, axis=0) / K.sum(lengths, axis=0), 'float32')
    # return Lambda(lambda x: x[0]/x[1])([np.sum(num_same, axis=0), np.sum(lengths, axis=0)])

# %%
check_pred(np.float32(predY),predictions)
# Out:
# ok
# 0.7451238

# %%
model.evaluate([predX,predAttm,predPosIds], predY,verbose = 1)
# Out:
# 983/983 [==============================] - 16s 17ms/step
# [12.544747370063106,
#  0.10435176640748978,
#  0.06176137179136276,
#  0.1551990658044815]

# %%
trainY = np.zeros(trainY.shape)
print(np.sum(trainY))
# Out:
# 0.0

# %%
del predPosIds
del predX
del predAttm
del predY

# %% [markdown]
# **Accuracy** **Experiments**

# %%
sums_ =  np.sum(predX,axis=-1)
print(sums_.shape)

sums__=  np.sum(predY,axis=-1)
print(sums__.shape)
# Out:
# (1213, 700)
# (1213, 700)

# %%
len_=np.zeros((predX.shape[0]))
for i in range(sums_.shape[0]):
    for j in range(700):
        if sums_[i,j]==0:
            len_[i] = j
            break
        if j==699:
            len_[i] = 700
print(len(len_))

len__=np.zeros((predX.shape[0]))
for i in range(sums__.shape[0]):
    for j in reversed(range(700)):
        if sums__[i,j]==1:
            len__[i] = j+1
            break
print(len(len__))
# Out:
# 1213
# 1213

# %%
print(len_==len__)
# Out:
# [ True  True  True ...  True  True  True]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(len_)
plt.show()

# %%
cnt_large_400 = 0
for i in range(len_.shape[0]):
    cur_len = len_[i]

    if cur_len>=600:
        cnt_large_400 +=1
cnt_large_400
# Out:
# 23

# %%
def get_pred(y_true,y_predict):
    mask = np.sum(y_true, axis=2)
    y_pred_labels = np.argmax(y_predict, axis=2).astype(np.float32)
    y_true_labels = np.argmax(y_true, axis=2).astype(np.float32)
    print('ok')
    is_same = np.equal(
        y_true_labels, y_pred_labels)
    num_same = np.sum(is_same * mask, axis=1)
    lengths = np.sum(mask, axis=1)
    return (is_same * mask,mask)

# %%
got = get_pred(np.float32(predY),predictions)
# Out:
# ok

# %%
print(got[0].shape)
# Out:
# (1213, 700)

# %%
preds_ = got[0]
mask_ = got[1]


cnt_save = 0
for cur in range(len_.shape[0]):

    if len_[cur] >= 600:
        x_ = []
        y_ = []
        plt.figure(figsize=(100, 20))
        for i in range( 700 ):

            # if i >400:

            if mask_[cur, i]==1:
                ress = preds_ [ cur,i]
                x_.append(i)
                y_.append( 5 + 5*ress)
        # plt.plot(x_, y_)
        plt.scatter(x_, y_)
        plt.savefig('/content/drive/MyDrive/scatter600plus'+str(cur)+'.png')
        cnt_save+=1
        if(cnt_save==20):
            break
        print('ok')
        # break



# # line 1 points
# x1 = [1,2,3]
# y1 = [2,4,1]
# # plotting the line 1 points
# plt.plot(x1, y1, label = "line 1")
 
# # line 2 points
# x2 = [1,2,3]
# y2 = [4,1,3]
# # plotting the line 2 points
# plt.plot(x2, y2, label = "line 2")
 
# # naming the x axis
# plt.xlabel('x - axis')
# # naming the y axis
# plt.ylabel('y - axis')
# # giving a title to my graph
# plt.title('Two lines on same graph!')
 
# # show a legend on the plot
# plt.legend()
 
# # function to show the plot
# plt.show()

# %%
# preds_ = got[0]
# mask_ = got[1]

# dif__ = 100
# for rng in range(0,700,100):
#     sumCor_left = np.sum(preds_[:,rng:], dtype=np.float32)
#     sumCor_right = np.sum(preds_[:,sep_len:], dtype=np.float32)
#     sumTot_left = np.sum(mask_[:,:sep_len], dtype=np.float32)
#     sumTot_right = np.sum(mask_[:,sep_len:], dtype=np.float32)


# preds_ = got[0]
# mask_ = got[1]

dif__ = 30
acc_rng = []
acc_rng_id =[]
for rng in range(0,700,dif__):
    sumCor= np.sum(preds_[:,rng: min(700, rng+dif__)], dtype=np.float32)
    sumTot = max(np.sum(mask_[:,rng: min(700, rng+dif__)], dtype=np.float32),1)

    acc_rng.append(sumCor / sumTot)
    acc_rng_id.append(min(700, rng+dif__))
    # print('Acc in range: '+str(rng)+' - ' +str(min(700, rng+dif__))+' ---> '+str(sumCor / sumTot))


x =acc_rng_id
y = acc_rng

plt.figure(figsize=(10, 5))
plt.plot(x, y)
 
plt.xlabel('x - axis')
plt.ylabel('y - axis')
plt.title('Acc graph per '+str(dif__))
plt.savefig('/content/drive/MyDrive/bio-data/amlan22nov/acc-plots-per-'+str(dif__)+'.png')
plt.show()

# %%
os.mkdir('/content/drive/MyDrive/bio-data/training-needs')

# %%
for file in  os.listdir('/content/drive/MyDrive/bio-data'):
    if file[-3:]=='npy':
        shutil.copy('/content/drive/MyDrive/bio-data/'+file, '/content/drive/MyDrive/bio-data/training-needs/'+file)

# %%
import os, shutil
def make_archive(source, destination):
        base = os.path.basename(destination)
        name = base.split('.')[0]
        format = base.split('.')[1]
        archive_from = os.path.dirname(source)
        archive_to = os.path.basename(source.strip(os.sep))
        shutil.make_archive(name, format, archive_from, archive_to)
        shutil.move('%s.%s'%(name,format), destination)

make_archive('/content/drive/MyDrive/bio-data/training-needs', '/content/drive/MyDrive/bio-data/training-needs.zip')
